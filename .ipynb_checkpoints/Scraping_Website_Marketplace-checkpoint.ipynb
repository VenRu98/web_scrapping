# %% [markdown]
# # Scrapping Website Marketplace
#
# # Proses Pembuatan Scrapping dengan Target Tokopedia
#
# ## Scraping dengan Beautiful Soup 4
# ### 1.Mempersiapkan Tools
#
# Sebelum Melakukan Scrapping dan ,
# Library yang dibutuhkan yaitu:
# * Selenium
# * Beautiful Soup 4
#
# Library Tersebut Dapat di install dengan python3 yaitu:
#
# * ```pip install selenium```
# * ```pip install beautifulsoup4```
#
# Mempersiapkan Aplikasi Browser dan Driver Browser:
# * Aplikasi Browser sudah tersintall
# * Driver Browser sudah terinstall
# * Aplikasi dan Driver harus memiliki Versi yang sama
#
# Proses Installasi
#
# * Dengan Firefox
#     1. Jika Belum memiliki Browser Firefox, dapat di [Download](https://download.mozilla.org/?product=firefox-stub&os=win&lang=en-US&attribution_code=c291cmNlPXd3dy5nb29nbGUuY29tJm1lZGl1bT1yZWZlcnJhbCZjYW1wYWlnbj0obm90IHNldCkmY29udGVudD0obm90IHNldCkmZXhwZXJpbWVudD0obm90IHNldCkmdmFyaWF0aW9uPShub3Qgc2V0KSZ1YT1jaHJvbWU.&attribution_sig=774d9972789664be6672b065e7f33820ea1cb1e7bafb5ea8c6b2a4f4bc207c70)
#     2. Jika sudah, anda dapat memeriksa browser anda, dibawah ini adalah caranya:
#         ![firefox.png](attachment:firefox.png)![firefox_1.png](attachment:firefox_1.png)![firefox_2.png](attachment:firefox_2.png)
#     3. Intal driver browsing sesuai dengan versi aplikasi browsing [Download](https://github.com/mozilla/geckodriver/releases)
#
# * Dengan Chrome
#     1. Jika Belum memiliki Browser Chrome, dapat di [Download](https://dl.google.com/tag/s/appguid%3D%7B8A69D345-D564-463C-AFF1-A69D9E530F96%7D%26iid%3D%7BD6B35C78-230B-9B28-CF32-7395FA19234C%7D%26lang%3Den%26browser%3D4%26usagestats%3D1%26appname%3DGoogle%2520Chrome%26needsadmin%3Dprefers%26ap%3Dx64-stable-statsdef_1%26installdataindex%3Dempty/update2/installers/experimental/0/ChromeSetup.exe?src=1&filename=ChromeSetup.exe)
#     2. Jika sudah, anda dapat memeriksa browser anda, dibawah ini adalah caranya:
#        ![chrome.png](attachment:chrome.png) ![chrome_1.png](attachment:chrome_1.png)
#     3. Intal driver browsing sesuai dengan versi aplikasi browsing [Download](https://chromedriver.chromium.org/downloads)
#
#
# Pada kali ini akan Scraping Website Tokopedia:
#
# ### 2.Import Library dan Generate Scrapping
# * Mengimport Library <ins>Beautiful Soup 4</ins> dan <ins>Requests</ins>

# %%
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# * Dibawah ini adalah template link request untuk melakukan pencaring, <br>
# Kemudian program akan meminta input user untuk barang yang akan dicari

# %%
linkURL="https://www.tokopedia.com/search?st=product&q="

linkTool=input("Mencari Barang: ")
linkTool=linkTool.replace(" ", "+")
# Out:
# Mencari Barang: lampu

# %% [markdown]
# * Dibawah ini program akan melakukan request jika input sudah didapatkan.

# %%
page = requests.get(linkURL+linkTool,timeout=2)

# %% [markdown]
# * Diatas ini error, karena requests langsung terhadap link tokopedia, maka akan error seperti ini karenakan tidak menggunakan user agent, yang seolah-olah mengakses web tersebut menggunakan user agent tersebut.
# * Maka dari itu, Dibawah ini adalah code untuk user agent

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.50 Safari/537.36'
}
page = requests.get(linkURL+linkTool,headers=headers)

# %%
scrapping=BeautifulSoup(page.content,'lxml')
print(scrapping)

# %% [markdown]
# * jika menggunakan code di atas ini,<br>requests get terhadap target URL, hasil scrpaping data website akan di dapatkan,<br>
# __Tetapi__ javascript tidak akan jalan, karena dengan requests tidak menjalankan javascript.

# %% [markdown]
# ***
# * Mulai dari sini, program akan memulai scraping
# * maka dari itu, harus di import library __selenium__ yang berfungsi untuk menjalankan engine driver browser.<br>
# hal ini bermanfaat terhadap website scrapping untuk menjalankan javascript

# %%
from selenium import webdriver

# %% [markdown]
# * setelah import library, pastikan browser driver dan aplikasi browser sudah terinstall di perangkat. <br>
# patikan juga browser driver dan aplikasi browser harus memiliki versi yang sama.
# * dalam scrapping kali ini, saya akan menggunakan chrome sebagai tools yang saya gunakan  untuk scrapping
# * Jangan lupa untuk menyertakan user agent, dengan membuat variable user agent terlebih dahulu pada kode di bawah ini.

# %%
user_agent = 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.50 Safari/537.36'

# %% [markdown]
# * Pada option web driver, akan di konfigurasi seperti ini:

# %%
options = webdriver.ChromeOptions()
options.add_argument('--incognito')
options.add_argument('user-agent={0}'.format(user_agent))
options.add_argument('--headless')

# %% [markdown]
# > Penjelasan option:
# > * --incognito = tidak menyimpan jejak pencarian yang dilakukan.
# > * --headless = supaya UI tidak di munculkan yang bermanfaat supaya proses scrapping lebih cepat.
# > * --user agent = berguna untuk dapat bernegosiasi dengan server website

# %% [markdown]
# * Kemudian masukkan option tersebut ke dalam konfigurasi chrome driver di bawah ini.

# %%
driver = webdriver.Chrome(options=options)

# %% [markdown]
# * lakukan scrapping dengan generate isi page_source, kemudian generate source code dengan BeautifulSoup seperti code di bawah ini.

# %%
driver.get(linkURL+linkTool)

# %%
content = driver.page_source
scrapping = BeautifulSoup(content,'lxml')
print(scrapping)
# Out:
# <html data-rh="lang" lang="id"><head>
# <title>Jual lampu | Tokopedia</title>
# <meta charset="utf-8"/>
# <meta content="initial-scale=1, minimum-scale=1, maximum-scale=5, user-scalable=yes, width=device-width" name="viewport"/>
# <link crossorigin="" href="https://ecs7.tokopedia.net" rel="preconnect"/><link href="https://ecs7.tokopedia.net" rel="dns-prefetch"/>
# <link crossorigin="" href="https://gql.tokopedia.com" rel="preconnect"/><link href="https://gql.tokopedia.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://adservice.google.com" rel="preconnect"/><link href="https://adservice.google.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://certify-js.alexametrics.com" rel="preconnect"/><link href="https://certify-js.alexametrics.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://hub.tokopedia.com" rel="preconnect"/><link href="https://hub.tokopedia.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://sslwidget.criteo.com" rel="preconnect"/><link href="https://sslwidget.criteo.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://websdk.moengage.com" rel="preconnect"/><link href="https://websdk.moengage.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://www.google.com" rel="preconnect"/><link href="https://www.google.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://www.google-analytics.com" rel="preconnect"/><link href="https://www.google-analytics.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://www.googletagmanager.com" rel="preconnect"/><link href="https://www.googletagmanager.com" rel="dns-prefetch"/>
# <link href="/manifest.json" rel="manifest"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="Tokopedia" name="apple-mobile-web-app-title"/>
# <meta content="#42b549" name="theme-color"/>
# <style type="text/css">/*! normalize.css v7.0.0 | MIT License | github.com/necolas/normalize.css */html{line-height:1.15;-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%}body{margin:0}article,aside,footer,header,nav,section{display:block}h1{font-size:2em;margin:.67em 0}figcaption,figure,main{display:block}figure{margin:1em 40px}hr{box-sizing:content-box;height:0;overflow:visible}pre{font-family:monospace,monospace;font-size:1em}a{background-color:transparent;-webkit-text-decoration-skip:objects}abbr[title]{border-bottom:none;text-decoration:underline;text-decoration:underline dotted}b,strong{font-weight:inherit}b,strong{font-weight:bolder}code,kbd,samp{font-family:monospace,monospace;font-size:1em}dfn{font-style:italic}mark{background-color:#ff0;color:#000}small{font-size:80%}sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline}sub{bottom:-.25em}sup{top:-.5em}audio,video{display:inline-block}audio:not([controls]){display:none;height:0}img{border-style:none}svg:not(:root){overflow:hidden}button,input,optgroup,select,textarea{font-family:sans-serif;font-size:100%;line-height:1.15;margin:0}button,input{overflow:visible}button,select{text-transform:none}[type=reset],[type=submit],button,html [type=button]{-webkit-appearance:button}[type=button]::-moz-focus-inner,[type=reset]::-moz-focus-inner,[type=submit]::-moz-focus-inner,button::-moz-focus-inner{border-style:none;padding:0}[type=button]:-moz-focusring,[type=reset]:-moz-focusring,[type=submit]:-moz-focusring,button:-moz-focusring{outline:1px dotted ButtonText}fieldset{padding:.35em .75em .625em}legend{box-sizing:border-box;color:inherit;display:table;max-width:100%;padding:0;white-space:normal}progress{display:inline-block;vertical-align:baseline}textarea{overflow:auto}[type=checkbox],[type=radio]{box-sizing:border-box;padding:0}[type=number]::-webkit-inner-spin-button,[type=number]::-webkit-outer-spin-button{height:auto}[type=search]{-webkit-appearance:textfield;outline-offset:-2px}[type=search]::-webkit-search-cancel-button,[type=search]::-webkit-search-decoration{-webkit-appearance:none}::-webkit-file-upload-button{-webkit-appearance:button;font:inherit}details,menu{display:block}summary{display:list-item}canvas{display:inline-block}template{display:none}[hidden]{display:none}.async-hide{opacity:0!important}</style>
# <style type="text/css">:focus{outline:0}html{box-sizing:border-box;font-size:14px;font-family:'Open Sans',sans-serif}.font-open{font-family:'Open Sans',sans-serif}.font-nunito{font-family:'Nunito Sans',sans-serif}body,html{background:#fff !important;margin:0;padding:0;height:100%;color:rgba(0,0,0,.54)}*,::after,::before{box-sizing:inherit}::-webkit-input-placeholder{color:rgba(0,0,0,.26)}::-moz-placeholder{color:rgba(0,0,0,.26)}:-ms-input-placeholder{color:rgba(0,0,0,.26)}:-moz-placeholder{color:rgba(0,0,0,.26)}a{color:rgba(0,0,0,.7);text-decoration:none}body{padding:90px 0 0 0;}.input,input[type=text],select,textarea{-webkit-appearance:none}[type=search]{-webkit-appearance:none;outline-offset:0}input[type=number]::-webkit-inner-spin-button,input[type=number]::-webkit-outer-spin-button{-webkit-appearance:none;margin:.25em}.none{display:none}.u-clearfix::after,.u-clearfix::before{display:table;content:' '}.u-clearfix::after{clear:both}.u-inline-block{display:inline-block}.u-block{display:block}.u-center{text-align:center}</style>
# <link as="script" crossorigin="anonymous" data-chunk="main" href="https://ecs7.tokopedia.net/assets-tokopedia-lite/v2/zeus/production/runtime.60ad80716b0f2a7ec571.js" rel="preload"/>
# <link as="script" crossorigin="anonymous" data-chunk="main" href="https://ecs7.tokopedia.net/assets-tokopedia-lite/v2/zeus/production/unify.f3d5aa09358698ac6b05.js" rel="preload"/>
# <link as="script" crossorigin="anonymous" data-chunk="main" href="https://ecs7.tokopedia.net/assets-tokopedia-lite/v2/zeus/production/vendor.9da660b106b76786a819.js" rel="preload"/>
# <link as="script" crossorigin="anonymous" data-chunk="main" href="https://ecs7.tokopedia.net/assets-tokopedia-lite/v2/zeus/production/chunk.main.538c92b6c66417409fe7.js" rel="preload"/>
# <link as="script" crossorigin="anonymous" data-chunk="nonLoggedInCart" href="https://ecs7.tokopedia.net/assets-tokopedia-lite/v2/zeus/production/chunk.nonLoggedInCart.81165f3ae0a399f385c0.js" rel="preload"/>
# <link as="script" crossorigin="anonymous" data-chunk="nonLoggedIn" href="https://ecs7.tokopedia.net/assets-tokopedia-lite/v2/zeus/production/chunk.nonLoggedIn.31b46aa560cb9913789f.js" rel="preload"/>
# <link as="script" crossorigin="anonymous" data-chunk="search" href="https://ecs7.tokopedia.net/assets-tokopedia-lite/v2/zeus/production/chunk.vendors~search.d224ae3a08393eb69dce.js" rel="preload"/>
# <link as="script" crossorigin="anonymous" data-chunk="search" href="https://ecs7.tokopedia.net/assets-tokopedia-lite/v2/zeus/production/chunk.search.26fcdd50d6c4d0d30963.js" rel="preload"/>
# <link as="script" crossorigin="anonymous" data-chunk="srp-product-result" href="https://ecs7.tokopedia.net/assets-tokopedia-lite/v2/zeus/production/chunk.vendors~MembershipShopDetail~cart-widget-last-seen~catalog~categoryLevelOne~categoryView~discovery~h~dc81e582.b1c46718cc8a3f4fe989.js" rel="preload"/>
# <link as="script" crossorigin="anonymous" data-chunk="srp-product-result" href="https://ecs7.tokopedia.net/assets-tokopedia-lite/v2/zeus/production/chunk.vendors~after-sq~cart-widget-last-seen~home-login~home-non-login~login-popup~page-hot-detail~pdp-by-~173dfc1a.584153c7df4b89e40290.js" rel="preload"/>
# <link as="script" crossorigin="anonymous" data-chunk="srp-product-result" href="https://ecs7.tokopedia.net/assets-tokopedia-lite/v2/zeus/production/chunk.vendors~cart-list~catalog~category~categoryLevelOne~checkout~discovery~multiaddress~srp-product-resu~1b77d2c6.938d00e4bc65eb6b2f01.js" rel="preload"/>
# <link as="script" crossorigin="anonymous" data-chunk="srp-product-result" href="https://ecs7.tokopedia.net/assets-tokopedia-lite/v2/zeus/production/chunk.vendors~srp-catalog-result~srp-product-result~srp-profile-result~srp-shop-result.67219459e8f0519ff685.js" rel="preload"/>
# <link as="script" crossorigin="anonymous" data-chunk="srp-product-result" href="https://ecs7.tokopedia.net/assets-tokopedia-lite/v2/zeus/production/chunk.srp-product-result.768ec18596f28abd7936.js" rel="preload"/>
# <link href="https://ecs7.tokopedia.net/assets-tokopedia-lite/prod/icon144.png" rel="icon" sizes="144x144" type="image/png"/>
# <link href="https://ecs7.tokopedia.net/assets-tokopedia-lite/prod/icon144.png" rel="apple-touch-icon" sizes="144x144" type="image/png"/>
# <link href="https://ecs7.tokopedia.net/assets-tokopedia-lite/prod/icon192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="https://ecs7.tokopedia.net/assets-tokopedia-lite/prod/icon192.png" rel="apple-touch-icon" sizes="192x192" type="image/png"/>
# <link href="https://ecs7.tokopedia.net/assets-tokopedia-lite/prod/icon512.png" rel="icon" sizes="512x512" type="image/png"/>
# <link href="https://ecs7.tokopedia.net/assets-tokopedia-lite/prod/icon512.png" rel="apple-touch-icon" sizes="512x512" type="image/png"/>
# <meta content="Jual lampu | Tokopedia" data-rh="true" name="title"/><meta content="Jual beli online produk lampu hanya di Tokopedia. Lengkap, murah, aman dan nyaman." data-rh="true" name="description"/><meta content="Jual lampu | Tokopedia" data-rh="true" property="og:title"/><meta content="Jual beli online produk lampu hanya di Tokopedia. Lengkap, murah, aman dan nyaman." data-rh="true" property="og:description"/><meta content="https://www.tokopedia.com/search?st=product&amp;q=lampu" data-rh="true" property="og:url"/><meta content="/search?st=product&amp;q=lampu" data-rh="true" name="branch:deeplink:$ios_deeplink_path"/><meta content="/search?st=product&amp;q=lampu" data-rh="true" name="branch:deeplink:$android_deeplink_path"/><meta content="https://www.tokopedia.com/search?st=product&amp;q=lampu" data-rh="true" name="branch:deeplink:$desktop_url"/><meta content="https://www.tokopedia.com/search?st=product&amp;q=lampu" data-rh="true" name="branch:deeplink:$android_url"/><meta content="https://www.tokopedia.com/search?st=product&amp;q=lampu" data-rh="true" name="branch:deeplink:$ios_url"/><meta content="summary_large_image" data-rh="true" name="twitter:card"/><meta content="@tokopedia" data-rh="true" name="twitter:site"/><meta content="@tokopedia" data-rh="true" name="twitter:creator"/><meta content="Jual lampu | Tokopedia" data-rh="true" name="twitter:title"/><meta content="Jual beli online produk lampu hanya di Tokopedia. Lengkap, murah, aman dan nyaman." data-rh="true" name="twitter:description"/><meta content="searchpage" data-rh="true" name="page-type"/>
# <link data-rh="true" href="https://www.tokopedia.com/search?st=product&amp;q=lampu" rel="canonical"/><link data-rh="true" href="https://m.tokopedia.com/search?st=product&amp;q=lampu" media="only screen and (max-width: 640px)" rel="alternate"/>
# <style>@font-face{font-family:'Nunito Sans';font-style:normal;font-weight:300;font-display:swap;src:local('Nunito Sans Light'),local('NunitoSans-Light'),url(https://fonts.gstatic.com/s/nunitosans/v5/pe03MImSLYBIv1o4X1M8cc8WAc5iU1ECVZl_86Y.woff2) format('woff2');unicode-range:U+0102-0103,U+0110-0111,U+0128-0129,U+0168-0169,U+01A0-01A1,U+01AF-01B0,U+1EA0-1EF9,U+20AB}@font-face{font-family:'Nunito Sans';font-style:normal;font-weight:300;font-display:swap;src:local('Nunito Sans Light'),local('NunitoSans-Light'),url(https://fonts.gstatic.com/s/nunitosans/v5/pe03MImSLYBIv1o4X1M8cc8WAc5jU1ECVZl_86Y.woff2) format('woff2');unicode-range:U+0100-024F,U+0259,U+1E00-1EFF,U+2020,U+20A0-20AB,U+20AD-20CF,U+2113,U+2C60-2C7F,U+A720-A7FF}@font-face{font-family:'Nunito Sans';font-style:normal;font-weight:300;font-display:swap;src:local('Nunito Sans Light'),local('NunitoSans-Light'),url(https://fonts.gstatic.com/s/nunitosans/v5/pe03MImSLYBIv1o4X1M8cc8WAc5tU1ECVZl_.woff2) format('woff2');unicode-range:U+0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+2000-206F,U+2074,U+20AC,U+2122,U+2191,U+2193,U+2212,U+2215,U+FEFF,U+FFFD}@font-face{font-family:'Nunito Sans';font-style:normal;font-weight:400;font-display:swap;src:local('Nunito Sans Regular'),local('NunitoSans-Regular'),url(https://fonts.gstatic.com/s/nunitosans/v5/pe0qMImSLYBIv1o4X1M8cceyI9tAcVwob5A.woff2) format('woff2');unicode-range:U+0102-0103,U+0110-0111,U+0128-0129,U+0168-0169,U+01A0-01A1,U+01AF-01B0,U+1EA0-1EF9,U+20AB}@font-face{font-family:'Nunito Sans';font-style:normal;font-weight:400;font-display:swap;src:local('Nunito Sans Regular'),local('NunitoSans-Regular'),url(https://fonts.gstatic.com/s/nunitosans/v5/pe0qMImSLYBIv1o4X1M8ccezI9tAcVwob5A.woff2) format('woff2');unicode-range:U+0100-024F,U+0259,U+1E00-1EFF,U+2020,U+20A0-20AB,U+20AD-20CF,U+2113,U+2C60-2C7F,U+A720-A7FF}@font-face{font-family:'Nunito Sans';font-style:normal;font-weight:400;font-display:swap;src:local('Nunito Sans Regular'),local('NunitoSans-Regular'),url(https://fonts.gstatic.com/s/nunitosans/v5/pe0qMImSLYBIv1o4X1M8cce9I9tAcVwo.woff2) format('woff2');unicode-range:U+0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+2000-206F,U+2074,U+20AC,U+2122,U+2191,U+2193,U+2212,U+2215,U+FEFF,U+FFFD}@font-face{font-family:'Nunito Sans';font-style:normal;font-weight:800;font-display:swap;src:local('Nunito Sans ExtraBold'),local('NunitoSans-ExtraBold'),url(https://fonts.gstatic.com/s/nunitosans/v5/pe03MImSLYBIv1o4X1M8cc8aBc5iU1ECVZl_86Y.woff2) format('woff2');unicode-range:U+0102-0103,U+0110-0111,U+0128-0129,U+0168-0169,U+01A0-01A1,U+01AF-01B0,U+1EA0-1EF9,U+20AB}@font-face{font-family:'Nunito Sans';font-style:normal;font-weight:800;font-display:swap;src:local('Nunito Sans ExtraBold'),local('NunitoSans-ExtraBold'),url(https://fonts.gstatic.com/s/nunitosans/v5/pe03MImSLYBIv1o4X1M8cc8aBc5jU1ECVZl_86Y.woff2) format('woff2');unicode-range:U+0100-024F,U+0259,U+1E00-1EFF,U+2020,U+20A0-20AB,U+20AD-20CF,U+2113,U+2C60-2C7F,U+A720-A7FF}@font-face{font-family:'Nunito Sans';font-style:normal;font-weight:800;font-display:swap;src:local('Nunito Sans ExtraBold'),local('NunitoSans-ExtraBold'),url(https://fonts.gstatic.com/s/nunitosans/v5/pe03MImSLYBIv1o4X1M8cc8aBc5tU1ECVZl_.woff2) format('woff2');unicode-range:U+0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+2000-206F,U+2074,U+20AC,U+2122,U+2191,U+2193,U+2212,U+2215,U+FEFF,U+FFFD}@font-face{font-family:'Open Sans';font-style:normal;font-weight:300;font-display:swap;src:local('Open Sans Light'),local('OpenSans-Light'),url(https://fonts.gstatic.com/s/opensans/v17/mem5YaGs126MiZpBA-UN_r8OX-hpKKSTj5PW.woff2) format('woff2');unicode-range:U+0460-052F,U+1C80-1C88,U+20B4,U+2DE0-2DFF,U+A640-A69F,U+FE2E-FE2F}@font-face{font-family:'Open Sans';font-style:normal;font-weight:300;font-display:swap;src:local('Open Sans Light'),local('OpenSans-Light'),url(https://fonts.gstatic.com/s/opensans/v17/mem5YaGs126MiZpBA-UN_r8OVuhpKKSTj5PW.woff2) format('woff2');unicode-range:U+0 ...
# <script async="" src="https://www.google-analytics.com/plugins/ua/ec.js" type="text/javascript"></script><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://www.google-analytics.com/gtm/js?id=GTM-T9Q3S3H&amp;t=gtm2&amp;cid=98315978.1587535790" type="text/javascript"></script><script async="" src="//www.googletagmanager.com/gtm.js?id=GTM-TN8CNF"></script><script async="" id="tkpd-iris-tracker-new" src="https://ecs7.tokopedia.net/production/v2/20032020/datalayer-client-web.latest.js"></script><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://certify-js.alexametrics.com/atrk.js" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-TN8CNF"></script><script type="text/javascript">window.__CONSTANTS__={"SW_EXCLUDE_ARRAY":["^\\/mybills","^\\/iklan","^\\/kejutan","^\\/kotak-kejutan","^\\/redeem","^\\/seller","^\\/saldo","^\\/payment","^\\/flash-sale","^\\/about","^\\/bantuan","^\\/contact","^\\/ajax","^\\/logistic","\\.pl","\\.txt","\\/__","\\/help\\/inbox","^\\/.well-known\\/?","^\\/[\\w-]+\\/review","^\\/[\\w-]+\\/talk","^\\/accounts-logout","^\\/add-product","^\\/after_sq","^\\/agen","^\\/akamai","^\\/angsuran","^\\/assets\\/","^\\/asuransi","^\\/belajar","^\\/berbagi","^\\/blog","^\\/bpjs","^\\/broadcast","^\\/cart","^\\/catalog","^\\/chat","^\\/deals","^\\/donasi-online","^\\/edit-product","^\\/edu","^\\/emas","^\\/e-pharmacy","^\\/events","^\\/find\\/","^\\/flight","^\\/fm\\/","^\\/forms\\/","^\\/gift-card","^\\/help","^\\/hotel","^\\/inbox-reputation","^\\/inbox-talk","^\\/jasa\\/","^\\/kartu-kredit","^\\/kartu-prakerja","^\\/kereta-api","^\\/kredit-motor","^\\/kredivo","^\\/langganan","^\\/login","^\\/logout","^\\/manage-product","^\\/mitra-toppers","^\\/mpn","^\\/my-shop","^\\/myshop","^\\/order\\/invoice","^\\/otp","^\\/ovo-paylater","^\\/ovo","^\\/pajak","^\\/paket-data","^\\/pascabayar","^\\/payment-list","^\\/pdam","^\\/pengaturan-diskon","^\\/people\\/","^\\/pgn","^\\/pinjaman-online","^\\/play","^\\/pln","^\\/product-camp","^\\/produk-digital","^\\/promo","^\\/proteksi","^\\/pulsa","^\\/register","^\\/reksa-dana","^\\/reset","^\\/resolution-center\\/","^\\/retribusi","^\\/roaming","^\\/s\\/","^\\/s\\/umroh","^\\/s\\/donasi","^\\/salam","^\\/saldo-prioritas","^\\/seru","^\\/settings","^\\/snapshot_product","^\\/streaming","^\\/tagihan-listrik","^\\/tagihan","^\\/telepon","^\\/tokopediaumroh","^\\/tokopoints","^\\/top-up","^\\/tv-kabel","^\\/v1\\/","^\\/v2\\/","^\\/voucher","^\\/appauth\\/code","^\\/discovery\\/tukar-tambah","^\\/buka-toko-gratis","^\\/buka-toko-online-gratis","^\\/official-store\\/registration","^\\/mitra","^\\/official-store\\/brand\\/","^\\/official-store\\/brand","^\\/official-store\\/store-display-management","^\\/official-store\\/secdep\\/download","^\\/careers","^\\/pasang-tv-kabel"],"ACCOUNTS_PIXEL":"https://accounts.tokopedia.com/marketplace/pixel","ACCOUNTS_HOSTNAME":"https://accounts.tokopedia.com","ANALYTIC_UA":"YOUR-UA-ID-HERE","API_ROOT_OCL":"https://accounts.tokopedia.com/api","CHAT_WS":"wss://chat.tokopedia.com/connect","CHAT_HOSTNAME":"https://chat.tokopedia.com","COOKIE_DOMAIN":".tokopedia.com","COOKIE_AUTOCOMPLETE":"_ID_autocomplete_","DIGITAL_COOKIE":"l","GQLHOST_GO":"https://gql.tokopedia.com","GQLHOST_NODE":"https://gql.tokopedia.com","GTM_CONTAINER_ID":"GTM-TN8CNF","HOSTNAME":"https://www.tokopedia.com","HUB_DATALAYER":"https://hub.tokopedia.com/iris/clients/web/datalayer-client-web.latest.js","OAUTH_CLIENT_ID":1001,"SELLER_HOSTNAME":"https://seller.tokopedia.com","SID_COOKIE":"_SID_Tokopedia_","TOPADS_HOSTNAME":"https://ta.tokopedia.com","X_DEVICE":"web","MOBILE_HOSTNAME":"https://m.tokopedia.com","HOTH":"https://ace.tokopedia.com/hoth","USER_OTP_TIMER":30,"PULSA_HOSTNAME":"https://pulsa.tokopedia.com","GOOGLE_APP_ID":"692092518182-rjgh0bja6q41dllpq2dptn134cmhiv9h.apps.googleus ...
# <script>bazadebezolkohpepadr="172722074"</script><script defer="" src="https://www.tokopedia.com/akam/11/a4b861b" type="text/javascript"></script><script charset="utf-8" crossorigin="anonymous" src="https://ecs7.tokopedia.net/assets-tokopedia-lite/v2/zeus/production/chunk.vendors~polyfills.26256e04393bab49f132.js"></script><script charset="utf-8" crossorigin="anonymous" src="https://ecs7.tokopedia.net/assets-tokopedia-lite/v2/zeus/production/chunk.polyfills.5e11fb31899c417dec47.js"></script><style data-emotion-css="jlk0mk i6183d 1lz1btd 4o66f 10x2v5k 1lvy9te a6abqo ovhcia 1s16om9 zopo9b 1s635gh 14r90fk oh6j69 1xjtxag irgsoc 1kyvjzs 1ix40yr 1j4f5q9 1amv76s qscw6i 1tmsi71 5dt8hb poh7b k639sw 1tbxokc 1801u8h 1jnwvl6 ogpi78 1iz87d3 1jx6p69 1rr78vg">@-webkit-keyframes animation-jlk0mk{0%{background-position:-300px;}100%{background-position:300px;}}@keyframes animation-jlk0mk{0%{background-position:-300px;}100%{background-position:300px;}}@-webkit-keyframes animation-i6183d{0%{-webkit-transform:translateY(-60%);-ms-transform:translateY(-60%);transform:translateY(-60%);}50%{-webkit-transform:translateY(60%);-ms-transform:translateY(60%);transform:translateY(60%);}100%{-webkit-transform:translateY(-60%);-ms-transform:translateY(-60%);transform:translateY(-60%);}}@keyframes animation-i6183d{0%{-webkit-transform:translateY(-60%);-ms-transform:translateY(-60%);transform:translateY(-60%);}50%{-webkit-transform:translateY(60%);-ms-transform:translateY(60%);transform:translateY(60%);}100%{-webkit-transform:translateY(-60%);-ms-transform:translateY(-60%);transform:translateY(-60%);}}@-webkit-keyframes animation-1lz1btd{0%{-webkit-transform:translateY(60%);-ms-transform:translateY(60%);transform:translateY(60%);}50%{-webkit-transform:translateY(-60%);-ms-transform:translateY(-60%);transform:translateY(-60%);}100%{-webkit-transform:translateY(60%);-ms-transform:translateY(60%);transform:translateY(60%);}}@keyframes animation-1lz1btd{0%{-webkit-transform:translateY(60%);-ms-transform:translateY(60%);transform:translateY(60%);}50%{-webkit-transform:translateY(-60%);-ms-transform:translateY(-60%);transform:translateY(-60%);}100%{-webkit-transform:translateY(60%);-ms-transform:translateY(60%);transform:translateY(60%);}}@-webkit-keyframes animation-4o66f{0%{background-color:#FFC400;-webkit-transform:scaleX(0);-ms-transform:scaleX(0);transform:scaleX(0);}25%{-webkit-transform:scaleX(0);-ms-transform:scaleX(0);transform:scaleX(0);}50%{-webkit-transform:scaleX(1);-ms-transform:scaleX(1);transform:scaleX(1);}75%{-webkit-transform:scaleX(1);-ms-transform:scaleX(1);transform:scaleX(1);}100%{background-color:#FFC400;-webkit-transform:translateX(100%);-ms-transform:translateX(100%);transform:translateX(100%);}}@keyframes animation-4o66f{0%{background-color:#FFC400;-webkit-transform:scaleX(0);-ms-transform:scaleX(0);transform:scaleX(0);}25%{-webkit-transform:scaleX(0);-ms-transform:scaleX(0);transform:scaleX(0);}50%{-webkit-transform:scaleX(1);-ms-transform:scaleX(1);transform:scaleX(1);}75%{-webkit-transform:scaleX(1);-ms-transform:scaleX(1);transform:scaleX(1);}100%{background-color:#FFC400;-webkit-transform:translateX(100%);-ms-transform:translateX(100%);transform:translateX(100%);}}@-webkit-keyframes animation-10x2v5k{0%{stroke-dasharray:1,200;stroke-dashoffset:0;}100%{stroke-dasharray:200,200;stroke-dashoffset:-125px;}}@keyframes animation-10x2v5k{0%{stroke-dasharray:1,200;stroke-dashoffset:0;}100%{stroke-dasharray:200,200;stroke-dashoffset:-125px;}}#chat-item-container{padding-inline-start:0px;margin-block-start:0px;margin-block-end:0px;}#chat-snippet{z-index:80 !important;}.chat-addlink-product__btn--buy:not([disabled]){background-color:#ff5722 !important;color:#fff !important;}.chat__search input{background:transparent !important;}.unf-user-dialog__content--mute{padding:32px 44px !important;}.receive-setting__desc .unf-toggle{position:absolute !important;top:30% !important;right:12px !important;}.unf-user-dialog__title{font-size:18px !important;fon ...
# <body>
# <noscript><div>Website tokopedia memerlukan javascript untuk dapat ditampilkan.</div></noscript>
# <div id="zeus-root"><div class="css-3lpl5n"><div class="css-yohxq zeus-header" id="zeus-header"><div class="css-1nzx3dd e90swyx0" id="header-main-wrapper"><div class="css-1mk6rmf"><div class="css-1t2cza5"><i class="css-5be620"></i><a class="css-7k41it" href="/mobile-apps/" rel="noopener noreferrer" target="_blank"> <!-- -->Download Tokopedia App</a></div><div class="css-1dm32rh e90swyx3"><a class="css-f0xez1" data-testid="btnHeaderAbout" href="/about/" rel="noopener noreferrer" target="_blank">Tentang Tokopedia</a><a class="css-f0xez1" data-testid="btnHeaderMitra" href="/mitra/" rel="noopener noreferrer" target="_blank">Mitra Tokopedia</a><a class="css-f0xez1" data-testid="btnHeaderSellerEdu" href="https://seller.tokopedia.com/edu/mulai-berjualan/" rel="noopener noreferrer" target="_blank">Mulai Berjualan </a><a class="css-f0xez1" data-testid="btnHeaderPromo" href="/promo/" rel="noopener noreferrer" target="_blank">Promo</a><a class="css-f0xez1" data-testid="btnHeaderHelp" href="/help/" rel="noopener noreferrer" target="_blank">Tokopedia Care</a></div></div><div class="css-1y7ij32"><a class="css-1mag7cs e90swyx1" data-testid="icnHeaderIcon" href="https://www.tokopedia.com"><img alt="tokopedia-logo" src="https://ecs7.tokopedia.net/assets-tokopedia-lite/v2/zeus/production/e5b8438b.svg"/></a><div class="css-1qr7rcv e19fui500"><div class="css-1iy09lx e19fui501" data-testid="btnHeaderCategory"><div class="css-vk082c" data-testid="headerText">Kategori</div></div></div><div class="css-nz1n1e e1til1zw1" id="search-container" width="70%"><form action="/search" class="css-w3ze74" method="get"><div class="css-1kxpl7k e1til1zw2" data-testid="txtHeaderSearchBar"><div class="css-ks91jt e1v0ehno0"><button aria-label="unf-search-btn" class="css-9gksxa e1v0ehno1" type="submit"></button><input class="css-1w2ezbs e16vycsw0" placeholder="Cari kolam renang" type="text" value="lampu"/></div></div></form></div><div class="css-k1xqhd" data-testid="btnHeaderCart"><div class="css-1i12xq8"><i class="css-a67q5r"></i></div></div><div class="css-1v8b07p"></div><div class="css-zkbhqe"><button class="css-2hev56" data-testid="btnHeaderLogin" type="button">Masuk</button><button class="css-19y7bxn" data-testid="btnHeaderRegister" type="button"> <!-- -->Daftar<!-- --> </button></div></div><div class="css-1h5mngq e18xnoc40"><a data-testid="trendkingKeywordList" href="https://www.tokopedia.com/find/tv-led">tv led</a><a data-testid="trendkingKeywordList" href="https://www.tokopedia.com/find/samsung-a20s">samsung a20s</a><a data-testid="trendkingKeywordList" href="https://www.tokopedia.com/find/stun-gun">stun gun</a><a data-testid="trendkingKeywordList" href="https://www.tokopedia.com/find/baju-anak-perempuan">baju anak perempuan</a><a data-testid="trendkingKeywordList" href="https://www.tokopedia.com/find/cetakan-kue">cetakan kue</a><a data-testid="trendkingKeywordList" href="https://www.tokopedia.com/find/gtx-1080">gtx 1080</a></div></div></div><div class="css-jau1bt"><div class="css-1c82svt"><div class="css-gfb3wv"><h5 class="css-gwtn89-unf-heading e1qvo2ff5">Filter</h5><div class="css-1257219"><div class="css-aak6qz-unf-accordion e1h89v725"><button class="css-12nwyfb-unf-accordion__header e1h89v721" data-unf="unf-accordion__header"><h6 class="css-jsut4p-unf-heading e1qvo2ff6">Kategori</h6><i class="css-16qkypa-unf-accordion__caret-icon e1h89v720" open=""></i></button><div class="css-1mi2zn5 e1h89v722" data-unf="unf-accordion__content" open="" style="height: auto;"><div data-unf="unf-accordion__content-wrapper"><div class="css-1cb34wj"><div class="css-1jke4yk"><div class="css-16tu08h"><button class="css-5uxrvt" data-testid="btnSRPDropDownCategoryFilter" type="button"><i></i></button><span data-testid="spnSRPLevel1Filter" title="Elektronik">Elektronik</span></div><div class="css-s07owd"><div class="css-1jke4yk"><div class="css-16tu08h"><button class="css-hk1u29" data-testid="btnSRPDropDownCategoryFilter" type="button"><i></i></button><span data-testid="spnSRPLevel ...
# <script>
#       "use strict";
#       window.addEventListener('DOMContentLoaded', function() {
#         window.ga && window.ga('create', 'UA-9801603-1', 'auto', { useAmpClientId: true });
#       });
#     </script>
# <script type="text/javascript">
#       window.initialGlobalState={"ssi":"","statusCode":200,"isBot":false,"path":"\u002Fsearch"};
#       window.__memoCache={"footer":{"data":{"seoFooter":{"footerGroup":[{"name":"Tokopedia","foreignName":"Tokopedia","footerLinks":[{"url":"https:\u002F\u002Fwww.tokopedia.com\u002Fabout\u002F","name":"Tentang Tokopedia","foreignName":"About Tokopedia","__typename":"FooterLink"},{"url":"https:\u002F\u002Fwww.tokopedia.com\u002Fcareers\u002F","name":"Karir","foreignName":"Career","__typename":"FooterLink"},{"url":"https:\u002F\u002Fwww.tokopedia.com\u002Fblog\u002F","name":"Blog","foreignName":"Blog","__typename":"FooterLink"},{"url":"https:\u002F\u002Fwww.tokopedia.com\u002Fsalam\u002F","name":"Tokopedia Salam","foreignName":"Tokopedia Salam","__typename":"FooterLink"},{"url":"https:\u002F\u002Fwww.tokopedia.com\u002Fhotel\u002F","name":"Hotel","foreignName":"Hotel","__typename":"FooterLink"},{"url":"https:\u002F\u002Fwww.bridestory.com\u002F","name":"Bridestory","foreignName":"Bridestory","__typename":"FooterLink"},{"url":"https:\u002F\u002Fwww.parentstory.com\u002F","name":"Parentstory","foreignName":"Parentstory","__typename":"FooterLink"},{"url":"https:\u002F\u002Fkamus.tokopedia.com\u002F","name":"Kamus Tokopedia","foreignName":"Tokopedia Dictionary","__typename":"FooterLink"},{"url":"https:\u002F\u002Fwww.tokopedia.com\u002Fofficial-store\u002F","name":"Official Store","foreignName":"Official Store","__typename":"FooterLink"},{"url":"https:\u002F\u002Fwww.tokopedia.com\u002Fmobile-apps\u002F","name":"Aplikasi Tokopedia","foreignName":"Tokopedia Apps","__typename":"FooterLink"},{"url":"https:\u002F\u002Fwww.tokopedia.com\u002Fdaftar-halaman\u002F","name":"Tagihan & Top up","foreignName":"Billing & Top up","__typename":"FooterLink"},{"url":"https:\u002F\u002Fwww.tokopedia.com\u002Fdeals\u002Fjakarta\u002F?ispulsa=1","name":"Deals Tokopedia","foreignName":"Deals Tokopedia","__typename":"FooterLink"},{"url":"https:\u002F\u002Fwww.tokopedia.com\u002Fkeuangan\u002F","name":"Keuangan","foreignName":"Finance","__typename":"FooterLink"},{"url":"https:\u002F\u002Fwww.tokopedia.com\u002Fdiscovery\u002Fbebas-ongkir","name":"Bebas Ongkir","foreignName":"Free Shipping","__typename":"FooterLink"},{"url":"https:\u002F\u002Fwww.tokopedia.com\u002Fdiscovery\u002Ftukar-tambah","name":"Tukar Tambah Handphone","foreignName":"Trade In Handphone","__typename":"FooterLink"},{"url":"https:\u002F\u002Fwww.tokopedia.com\u002Fs\u002Fumroh\u002F","name":"Paket Umroh","foreignName":"Umroh Package","__typename":"FooterLink"},{"url":"https:\u002F\u002Fwww.tokopedia.com\u002Fs\u002Fquran","name":"Alquran Online","foreignName":"Alquran Online","__typename":"FooterLink"},{"url":"https:\u002F\u002Fwww.tokopedia.com\u002Fdiscovery\u002Fkotak-kejutan","name":"Kotak Kejutan","foreignName":"Kotak Kejutan","__typename":"FooterLink"}],"__typename":"FooterGroup"},{"name":"Beli","foreignName":"Buy","footerLinks":[{"url":"https:\u002F\u002Ftiket.tokopedia.com\u002Fkereta-api\u002F","name":"Tiket Kereta","foreignName":"Train Ticket","__typename":"FooterLink"},{"url":"https:\u002F\u002Fwww.tokopedia.com\u002Fflight\u002F","name":"Tiket Pesawat","foreignName":"Flight Ticket","__typename":"FooterLink"},{"url":"https:\u002F\u002Fwww.tokopedia.com\u002Fevents\u002F","name":"Tiket Events","foreignName":"Ticket Events","__typename":"FooterLink"},{"url":"https:\u002F\u002Fwww.tokopedia.com\u002Fhot\u002F","name":"Hotlist","foreignName":"Hotlist","__typename":"FooterLink"},{"url":"https:\u002F\u002Fwww.tokopedia.com\u002Fp","name":"Kategori","foreignName":"Category","__typename":"FooterLink"}],"__typename":"FooterGroup"},{"name":"Jual","foreignName":"Sell","footerLinks":[{"url":"https:\u002F\u002Fseller.tokopedia.com\u002Fedu\u002F","name":"Pusat Edukasi Seller","foreignName":"Seller Education Centre","__typename":"FooterLink"},{"url":"https:\u002F\u002Fwww.tokopedia.com\u002Fmitra-toppers\u002F?nref=mtfoot","name":"Mitra Toppers","foreignName":"Mitra Toppers","__typename":"FooterLink"},{"url":"https:\u002F\u002Fseller.tokopedia.com\u002Fedu\u002Fofficial-store\u002F","name ...
#       window.__ismobileapp=false;
#       window.__cache={"ROOT_QUERY":{"isAuthenticated":0,"trending_keywords":{"type":"id","generated":true,"id":"$ROOT_QUERY.trending_keywords","typename":"TrendingKeywords"},"universe_placeholder({})":{"type":"id","generated":true,"id":"$ROOT_QUERY.universe_placeholder({})","typename":"UniversePlaceholder"}},"$ROOT_QUERY.trending_keywords.keywords.0":{"url":"https:\u002F\u002Fwww.tokopedia.com\u002Ffind\u002Ftv-led","keyword":"tv led","__typename":"Keyword"},"$ROOT_QUERY.trending_keywords.keywords.1":{"url":"https:\u002F\u002Fwww.tokopedia.com\u002Ffind\u002Fsamsung-a20s","keyword":"samsung a20s","__typename":"Keyword"},"$ROOT_QUERY.trending_keywords.keywords.2":{"url":"https:\u002F\u002Fwww.tokopedia.com\u002Ffind\u002Fstun-gun","keyword":"stun gun","__typename":"Keyword"},"$ROOT_QUERY.trending_keywords.keywords.3":{"url":"https:\u002F\u002Fwww.tokopedia.com\u002Ffind\u002Fbaju-anak-perempuan","keyword":"baju anak perempuan","__typename":"Keyword"},"$ROOT_QUERY.trending_keywords.keywords.4":{"url":"https:\u002F\u002Fwww.tokopedia.com\u002Ffind\u002Fcetakan-kue","keyword":"cetakan kue","__typename":"Keyword"},"$ROOT_QUERY.trending_keywords.keywords.5":{"url":"https:\u002F\u002Fwww.tokopedia.com\u002Ffind\u002Fgtx-1080","keyword":"gtx 1080","__typename":"Keyword"},"$ROOT_QUERY.trending_keywords.keywords.6":{"url":"https:\u002F\u002Fwww.tokopedia.com\u002Ffind\u002Fjas-hujan","keyword":"jas hujan","__typename":"Keyword"},"$ROOT_QUERY.trending_keywords.keywords.7":{"url":"https:\u002F\u002Fwww.tokopedia.com\u002Ffind\u002Fsamsung-note-9","keyword":"samsung note 9","__typename":"Keyword"},"$ROOT_QUERY.trending_keywords.keywords.8":{"url":"https:\u002F\u002Fwww.tokopedia.com\u002Ffind\u002Fvacuum-cleaner","keyword":"vacuum cleaner","__typename":"Keyword"},"$ROOT_QUERY.trending_keywords.keywords.9":{"url":"https:\u002F\u002Fwww.tokopedia.com\u002Ffind\u002Fcase-iphone-x","keyword":"case iphone x","__typename":"Keyword"},"$ROOT_QUERY.trending_keywords":{"keywords":[{"type":"id","generated":true,"id":"$ROOT_QUERY.trending_keywords.keywords.0","typename":"Keyword"},{"type":"id","generated":true,"id":"$ROOT_QUERY.trending_keywords.keywords.1","typename":"Keyword"},{"type":"id","generated":true,"id":"$ROOT_QUERY.trending_keywords.keywords.2","typename":"Keyword"},{"type":"id","generated":true,"id":"$ROOT_QUERY.trending_keywords.keywords.3","typename":"Keyword"},{"type":"id","generated":true,"id":"$ROOT_QUERY.trending_keywords.keywords.4","typename":"Keyword"},{"type":"id","generated":true,"id":"$ROOT_QUERY.trending_keywords.keywords.5","typename":"Keyword"},{"type":"id","generated":true,"id":"$ROOT_QUERY.trending_keywords.keywords.6","typename":"Keyword"},{"type":"id","generated":true,"id":"$ROOT_QUERY.trending_keywords.keywords.7","typename":"Keyword"},{"type":"id","generated":true,"id":"$ROOT_QUERY.trending_keywords.keywords.8","typename":"Keyword"},{"type":"id","generated":true,"id":"$ROOT_QUERY.trending_keywords.keywords.9","typename":"Keyword"}],"__typename":"TrendingKeywords"},"$ROOT_QUERY.universe_placeholder({}).data":{"keyword":"kolam renang","placeholder":"Cari kolam renang","__typename":"UniversePlaceholderResult"},"$ROOT_QUERY.universe_placeholder({})":{"data":{"type":"id","generated":true,"id":"$ROOT_QUERY.universe_placeholder({}).data","typename":"UniversePlaceholderResult"},"__typename":"UniversePlaceholder"}};
#       window.dataLayer=window.dataLayer || [];
#       window.NODE_ENV="production";
#       window.version="bb399fb7820e8f3ec0841ada9100ee4010658185";
#       window.xdevice="";
#       window.__shell=false;
#       window.__SHELL_REVISION__="SSR";
#     </script>
# <script crossorigin="anonymous" id="__LOADABLE_REQUIRED_CHUNKS__" type="application/json">[100,99,215,155,0,1,5,10,183]</script>
# <script crossorigin="anonymous" data-chunk="main" defer="" src="https://ecs7.tokopedia.net/assets-tokopedia-lite/v2/zeus/production/runtime.60ad80716b0f2a7ec571.js"></script>
# <script crossorigin="anonymous" data-chunk="main" defer="" src="https://ecs7.tokopedia.net/assets-tokopedia-lite/v2/zeus/production/unify.f3d5aa09358698ac6b05.js"></script>
# <script crossorigin="anonymous" data-chunk="main" defer="" src="https://ecs7.tokopedia.net/assets-tokopedia-lite/v2/zeus/production/vendor.9da660b106b76786a819.js"></script>
# <script crossorigin="anonymous" data-chunk="main" defer="" src="https://ecs7.tokopedia.net/assets-tokopedia-lite/v2/zeus/production/chunk.main.538c92b6c66417409fe7.js"></script>
# <script crossorigin="anonymous" data-chunk="nonLoggedInCart" defer="" src="https://ecs7.tokopedia.net/assets-tokopedia-lite/v2/zeus/production/chunk.nonLoggedInCart.81165f3ae0a399f385c0.js"></script>
# <script crossorigin="anonymous" data-chunk="nonLoggedIn" defer="" src="https://ecs7.tokopedia.net/assets-tokopedia-lite/v2/zeus/production/chunk.nonLoggedIn.31b46aa560cb9913789f.js"></script>
# <script crossorigin="anonymous" data-chunk="search" defer="" src="https://ecs7.tokopedia.net/assets-tokopedia-lite/v2/zeus/production/chunk.vendors~search.d224ae3a08393eb69dce.js"></script>
# <script crossorigin="anonymous" data-chunk="search" defer="" src="https://ecs7.tokopedia.net/assets-tokopedia-lite/v2/zeus/production/chunk.search.26fcdd50d6c4d0d30963.js"></script>
# <script crossorigin="anonymous" data-chunk="srp-product-result" defer="" src="https://ecs7.tokopedia.net/assets-tokopedia-lite/v2/zeus/production/chunk.vendors~MembershipShopDetail~cart-widget-last-seen~catalog~categoryLevelOne~categoryView~discovery~h~dc81e582.b1c46718cc8a3f4fe989.js"></script>
# <script crossorigin="anonymous" data-chunk="srp-product-result" defer="" src="https://ecs7.tokopedia.net/assets-tokopedia-lite/v2/zeus/production/chunk.vendors~after-sq~cart-widget-last-seen~home-login~home-non-login~login-popup~page-hot-detail~pdp-by-~173dfc1a.584153c7df4b89e40290.js"></script>
# <script crossorigin="anonymous" data-chunk="srp-product-result" defer="" src="https://ecs7.tokopedia.net/assets-tokopedia-lite/v2/zeus/production/chunk.vendors~cart-list~catalog~category~categoryLevelOne~checkout~discovery~multiaddress~srp-product-resu~1b77d2c6.938d00e4bc65eb6b2f01.js"></script>
# <script crossorigin="anonymous" data-chunk="srp-product-result" defer="" src="https://ecs7.tokopedia.net/assets-tokopedia-lite/v2/zeus/production/chunk.vendors~srp-catalog-result~srp-product-result~srp-profile-result~srp-shop-result.67219459e8f0519ff685.js"></script>
# <script crossorigin="anonymous" data-chunk="srp-product-result" defer="" src="https://ecs7.tokopedia.net/assets-tokopedia-lite/v2/zeus/production/chunk.srp-product-result.768ec18596f28abd7936.js"></script>
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-TN8CNF" style="display: none; visibility: hidden;" width="0"></iframe></noscript>
# <script type="text/javascript">(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!=='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-TN8CNF');</script>
# <!-- Start Alexa Certify Javascript --><script type="text/javascript">_atrk_opts={atrk_acct:"dGA7f1a4IQ0087",domain:"tokopedia.com",dynamic:!0},function(){ window.addEventListener('DOMContentLoaded', function(){var t=document.createElement("script");t.type="text/javascript",t.async=!0,t.src="https://certify-js.alexametrics.com/atrk.js";var e=document.getElementsByTagName("script")[0];e.parentNode.insertBefore(t,e)})}()</script><noscript><img alt="" height="1" src="https://certify.alexametrics.com/atrk.gif?account=dGA7f1a4IQ0087" style="display:none" width="1"/></noscript><!-- End Alexa Certify Javascript -->
# <noscript><img src="https://www.tokopedia.com/akam/11/pixel_a4b861b?a=dD01ZjUwZDQzNTkzOWQyYjEzNDQwZDJmMTRlZWIxNWMwNmI0NTE1ZjZiJmpzPW9mZg==" style="visibility: hidden; position: absolute; left: -999px; top: -999px;"/></noscript><script type="text/javascript">var _cf = _cf || []; _cf.push(['_setFsp', true]);  _cf.push(['_setBm', true]); _cf.push(['_setAu', '/assets/62f0092b158b5d209c8a1b8205d6']); </script><script src="/assets/62f0092b158b5d209c8a1b8205d6" type="text/javascript"></script>
# <div><span></span></div><div><span></span></div>
# <script id="" type="text/javascript">!function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","//connect.facebook.net/en_US/fbevents.js");fbq("init","1419424518349836");fbq("track","PageView");</script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=1419424518349836&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <script id="" type="text/javascript">fbq("track","Search");</script>
# <noscript>
# <img height="1" src="https://www.facebook.com/tr?id=1419424518349836&amp;ev=Search&amp;noscript=1" style="display:none" width="1"/>
# </noscript><script id="" type="text/javascript">analyticsEvent=function(a,b,c,d,e){dataLayer.push({event:"analyticsEvent",eventCategory:a,eventAction:b,eventLabel:c,eventValue:d,eventNonInt:e})};</script><script id="" type="text/javascript">(function(){var contact=google_tag_manager["GTM-TN8CNF"].macro(3);count=5;if(true){var topupButton=document.getElementById("topup-wallet-button");if(topupButton)topupButton.style.cssText="display:none !important";var saldoButton=document.getElementById("topup-saldo-button");if(saldoButton)saldoButton.style.cssText="display:none !important";var t=setInterval(function(){count--;var topupButton=document.getElementById("topup-wallet-button");if(topupButton)topupButton.style.cssText="display:none !important";var saldoButton=
# document.getElementById("topup-saldo-button");if(saldoButton)saldoButton.style.cssText="display:none !important";if(count<=0)clearInterval(t)},500)}})();</script><script id="" type="text/javascript">(function(b,e,g,l,h,a,c,d){b.moengage_object=h;t={};q=function(a){return function(){(b.moengage_q=b.moengage_q||[]).push({f:a,a:arguments})}};f="track_event add_user_attribute add_first_name add_last_name add_email add_mobile add_user_name add_gender add_birthday destroy_session add_unique_user_id moe_events track location_type_attribute".split(" ");for(k in f)t[f[k]]=q(f[k]);a=e.createElement(g);c=e.getElementsByTagName(g)[0];a.async=1;a.src=l;c.parentNode.insertBefore(a,c);b.moe=b.moe||function(a){d=
# a;return t};a.onload=function(){d&&(b[h]=moe(d));Moengage&&Moengage.call_web_push&&Moengage.call_web_push()}})(window,document,"script","https://cdn.moengage.com/webpush/moe_webSdk.min.latest.js","Moengage");Moengage=moe({app_id:"LNCME8HVKUEJIGXE2N0698H0",debug_logs:0});</script><script id="" type="text/javascript">(function(a){a="undefined";Moengage.add_unique_user_id(a)})(window);</script><img alt="" height="1" src="//insight.adsrvr.org/track/evnt/?adv=03e47t6&amp;ct=0:7r1u26z&amp;fmt=3" style="border-style:none;" width="1"/><script id="" type="text/javascript">window.init_iris=!0;function createScript(b){void 0===b&&(b={});var a=b,h=a.id,d=a.src,f=a.callback,e=a.async;e=void 0===e?!0:e;a=a.defer;a=void 0===a?!1:a;var g=document.getElementsByTagName("script")[0],c=document.createElement("script");c.id=h;c.src=d;c.async=e;c.defer=a;g.parentNode.insertBefore(c,g);f&&"function"===typeof f&&(c.onload=f);return b}
# function iris(){var b=google_tag_manager["GTM-TN8CNF"].macro(4),a=function(){var a="desktop",d="default_v2";b&&(a="mobile",d="default_mweb");return window&&window.datalayerClientWeb&&window.datalayerClientWeb.initializeGTMWithIris({container:"gtm",device:a,customEventField:"event_ga",defaultEventValue:d},"dataLayer",google_tag_manager["GTM-TN8CNF"].macro(5))};createScript({id:"tkpd-iris-tracker-new",src:google_tag_manager["GTM-TN8CNF"].macro(6),callback:a})}iris();</script></body></html>

# %% [markdown]
# * Untuk hasil scrapping, akan memunculkan banyak data.<br>
# untuk membatasinya, harus dibutuhkan input integer<br>
# supaya banyak data yang di keluarkan sesuai dengan yang dimaksud.

# %%
batas=int(input("Batas Kemunculan Barang: "))
# Out:
# Batas Kemunculan Barang: 4

# %% [markdown]
# ### 3.Proses Data

# %% [markdown]
# * Pada Website Topedia, hasil pencarian barang akan langsung di tujukan dengan barang rekomendasi,<br>
# selebihnya memunculkan barang dengan filter "paling sesuai"
# * di bawah ini adalah function untuk memproses data
# * Varibel 'Semua' untuk menampung data penjualan yang laku

# %%
Semua = scrapping.findAll('div', attrs={'class':'css-1g20a2m'})
count_data = 0 #initial count dari 0

# %%
count_data = 0 #initial count dari 0
# ALL
for data in Semua:
    if count_data==batas:
        break
    count_data+=1
    link=data.find('a')['href']
    print("Link\t: ",link)
    judul = data.find('span',attrs={'css-1bjwylw'})
    print("Judul\t: ",judul.text)
    harga = data.find('span',attrs={'css-o5uqvq'})
    print("Harga\t: ",harga.text)
    print()
# Out:
# Link	:  https://ta.tokopedia.com/promo/v1/clicks/8a-xgVY2gmUEo_nao_Ka6AJDUMVj9RzNrc1i6sJDUSC5rfB7q3YXUsthbm-7q3OBUstho_KRo_HOopjhbm-srcHi6sHOHmFiy3zwrfo5rM1i6sHFHidRHAyRHpr7HprhHsHRbm-pHOYDQfri6i-B812kgJxGgBBXZSgjH7NDZ325q1ONoAzvuVBd_1zooJY139xozJ77_Ozgq1hAZM2jZJ2Myp-3qcoW_MY-qMY2_uz-q1hAZS-q3cFpysoGqOKp_M2iH72DZ325q1OAZ9o-Q_ufyMO6QJBkQfBvuJ7F_7PqQ1NW_9z68MPR_OHFHVBku9xHu7gk392SPV2I1_zg8jBd_jPo8uBEgch-q9P2ysoGrVtaQIuyHB-Dy7yNrV2AZ_g-qjV2_JoGPMoWQcNxupuMy7xGPB2UuM2jzsBF3jo-ojBke3BHe72fyfODQMV9o3gsHMxfy7yNrV2AZ_g-qjV2_JoG8cz9uSBBusjF3uPj8jBkQfBizJydgjx6Hc-y8AxizJtdgjPR8jB2PfBsHjNfyfO3gBBXZSgjH7NDZ325q1OkyRBHqBBN_jzCP7NJ__zvzVVd_Oo-r7BX_M2iH72D3Ao6QVByZM2xe7jfZ32oP7O2oAoozVjp_92sHJOEyRxoqj7pZ3dFvZUDUSupg9-wq3ei6iUFUiFirfuprfB5QBY2gmUEUj2S_OYB8Jh-ufjagItRqu-JgM2Dzsujb3xpzMgXej-u_cPH8jzbZAPy_uBiQSxFQSumrIP59RCXzsuo_BzFg1DfgcW-6_BgzBVAQjPzq1KhZ1oHHJPmeR-O3cHa1BY1g3xFHuYcz1ut_sgxz12kg1y7qJUR332mZAzEZuVqgSB1UiFiy3hSUstirRzW9fFp9fFa9fFhUiFiQSuWyMua9fYM9fVjraUEHsnDUMNOQ3-BrBYxgIowrMuhUstaHmFiyfV79fBjraUE3pyFbAjd6ZFhHAU79ZFiQBYsy3Njq3zxPcuwy3zpUstR6ZFiy3-wPcupPmUEUjdibm-FQRo79fVDgaUEUMoFyOYpqcYF9RuXrZUDUSgBrSo2Qfdi6i-fHi-Y?management_type=1&src=search&r=https%3A%2F%2Fwww.tokopedia.com%2Finfitechindo%2Fbardi-smart-light-bulb-lamp-bohlam-iot-home-wifi-rgb-ww-9w-wireless%3Fsrc%3Dtopads&is_search=1&keywords=lampu&dv=desktop&ob=23&page=1&t=desktop
# Judul	:  BARDI Smart Light Bulb Lamp Bohlam IoT Home WIFI RGB WW 9W wireless
# Harga	:  Rp 99.900
#
# Link	:  https://ta.tokopedia.com/promo/v1/clicks/8a-xgVY2gmUE6AyRHpeNoiFiy3zwPIBFgZUEHZFircYpq9z2Qfdi6sUDUSz2Q31i6sJO6ArOHp1R6_JDUMoFyaUEoAnFbm-xgVYpyfYagZUEHsjfbsJ7HAK7HsHaHAyF6AeDUSHp9fh5gaUEUMuNZM2jZJ2M33NGPMep_Mh-qMY2_1o-r7BW_sCsQABE3BPc8ujagfBvq1Bd_uH7H7Y1Z_C6uJj7_92C8JYJgp-ve7BpZ3O7QcuygIgsQu-Myp-6PMoWu3Bvq1BRZ3BRq3-W69ugHBu2_fB-o1OE1_zqQuja39jFH7YJe_uHuV-2_BzVPVB9_M2vepV03jztqjOkz_Cg8j2k_s-uq1hAZSgsQ3hXyurOgB2IuSPyHMh0Z325q1OAZ9o-Q_BNyuPjrc-D69PsQ_B0gVP6HVKaQcW-qMY2_1o-r7BW69BxufzFyMFN8MVI69PyHMh0Z325q1OAZ9o-Qjyh3BxGouKp1MxqH7O2_fBGr7Oy8AxsHO-7gjxdr7OX8AxizJO2_JoG8Bja69BqusB2yf7NHfHau3Bvq1BN_S2zP1Nke_V6ucHp_32ooJOJypzv17BpZ3N6qMUpZMhyH7ND3uxGqMVAZ_g-qjjO_Mj78JNJe_z6zJBE_32CHjOJgpC-QsnYUiFiP9oBrBY2gmUEUsnibm-pg9opq3YX9fBjUstiZMPv9fud_JB9q_-j8sP21jzMqMhco3eWqIocgMNmeBuHg7hEzJWUoOxo33-X8ICXP1-FPfYwrcNco1O6uICBZpgjq7jN6uBc11oXzOV2ZAV-e7FFz7-ArSuyyp-Z9OzBqInh97gVz3x6oMVVZM2BzsztesPgqj-UoI2-1u2M8ueibm-xQcri6i-pPcOwQAowQA-wQAJibm-XP3Oig9-wQfgwy3zpUstaHmFiQSuWyMua9fVjrOYag9Ji6sUFbm-sy9zwq3zpUs2QosnD6_KNbAJFHszPbm-X9foxQMz2gcV7guYxgIHi6srNbm-xyBY7g9o7Usti_iUDUSC5rRzwy3hSUstiyRCs9RotQRCwP3NhUiFiPMuarfB5QiUEUSyaUS7?page=1&keywords=lampu&t=desktop&management_type=2&dv=desktop&r=https%3A%2F%2Fwww.tokopedia.com%2Fmitra-abadi%2Flampu-led-strip-smd-5050-rgb-dc-12v-ip67ip68-rubber-tube-waterproof%3Fsrc%3Dtopads&ob=23&src=search&is_search=1
# Judul	:  Lampu LED Strip SMD 5050 RGB DC 12V IP67/IP68 + Rubber Tube WATERPROOF
# Harga	:  Rp 90.000
#
# Link	:  https://ta.tokopedia.com/promo/v1/clicks/8a-xgVY2gmUEoAKfosnao_HDUMVj9RzNrc1i6sJDUSC5rfB7q3YXUstpbm-7q3OBUstho_KRo_HOopjhbm-srcHi6sKFHmFiy3zwrfo5rM1i6sUdoadposnfo_KNHsHNHsK7omFirpowQcYSUstig9BGqMzUZMggQj2fgAo6QJBkQfBoe7BpZ3O6HcoD692qu7gN3_-Sq1Y2Z9P-q9P2y_-3o3ea69BqzsBE3_UN8u2_Z_g-qjV2_JoGP3Uao32q17jfZ3208jNJqcOqqB2k_VzsoJOJqRz6z7jh_uHhqVja__zHuO-0_7Po81O11M2oQ17p3Bo-r7BW69BxufzFyMFNqO2yeMgxuOV2_fB-P7B2PfBiH72F3s-DPuKpeSBiHBUh3_oZgMV913Bvq1BRZ3BRq3UpZSCqHMhO3Ao6QfUpeMgxuOV2_fB-P7B2PfBs3VgDyfNDgMzIzMNs81jfZ3OR8cgU8I2jzpJdgjPR83gU8Ioo81BpZ3N6qMUpZMhyHj2Nysoj8B2_Z_g-qjjp_1H781OJu9xozJVE_uzsP7Y1gpz681BpZ3N6qMUpZMhyH7ND3uxGqMVAZ_g-qjj7_Sj78jNke_-6ucrO_32oo1OkgpC6e7tNUiFiP9oBrBY2gmUEUsnibm-pg9opq3YX9fBjUstiZMPv9fud_JB9q_-j8sP21jzMqMhco3eWqIocgMNmeBuHg7hEzJWUoOxo33-X8ICXP1-FPfYwrcNco1O6uICBZpgjq7jN6uBc11oXzOV2ZAV-e7FFz7-ArSuyyp-Z9OzBqInh97gVz3x6oMVVZM2BzsztesPgqj-UoI2-1u2M8ueibm-xQcri6i-pPcOwQAowQA-wQAJibm-XP3Oig9-wQfgwy3zpUstaHmFiQSuWyMua9fVjrOYag9Ji6sUFbm-sy9zwq3zpUs2QosHDoAnDH_UN6u7DUMNwyfVXgcBjy9zB9fVjraUEopjDUMVi9RzBrRei6i-6UiFircYpPVYxQcri6i-srcowrfx5rVYOQSJibm-fg9-pq3YXUstiPsUibm-sQIupPcua9fBj9RyaUstpop1NH97?dv=desktop&keywords=lampu&src=search&page=1&ob=23&is_search=1&r=https%3A%2F%2Fwww.tokopedia.com%2Fbohlamhid%2Fbohlam-lampu-hid-new-vios-autovision-carbon-d4r-35w-ac-garansi-2th%3Fsrc%3Dtopads&management_type=1&t=desktop
# Judul	:  Bohlam Lampu HID NEW VIOS AUTOVISION CARBON D4R 35W AC Garansi 2th
# Harga	:  Rp 327.000
#
# Link	:  https://ta.tokopedia.com/promo/v1/clicks/8a-xgVY2gmUEHsH7H_eOHsJDUMVj9RzNrc1i6sJDUSC5rfB7q3YXUst7bm-7q3OBUstho_KRo_HOopjhbm-srcHi6sHOHmFiy3zwrfo5rM1i6sUdoidd6_npHsna6AUFHpH7HaFirpowQcYSUstig9BGqMzUZMggQj2fgAo6QJBkQfBoe7BpZ3O6HcoD692qu7gN3_-Sq1Y2Z_zHqjJO_Bz-8jYJe_u6uJBE_7zCo1N_Z9o-Q9zDguxjPMoW1MgsHjNfyfOuq1Y2Z9P-q9P2yM7NPujau3Bvq1jO_92zoV2W3_-g8_np_7zCo1h11MB6uJu73uP6qjYAH3Wqzcxk_32VHVBEZM26HBu2_JoGPMoWQcNxupuM3jP3POKaQcW-qMY2_1o-r7BW69BxufzFyMFNPfoW63Wju7dF3A-Dq7BkQfBoe7BpZ37N83V9gICiQABEy1rNPOKaQcW-qMY2_1o-r7BXzsVq3JtO3AoZqVtp_3Bvq12p_uxd6cHp1SzMZIxp_3Nd6c-J_3BHe72E3_UN8u2363BsQ_jpyp-uq1Y2Z9B6uJBO_1zzo1OEe_zoqMod_BzSP7Nk33BHe72E3_UN8u23692qu7gN3_-Sq1Y2Z9BvzVBO_7z0P7OEZ9PoqMPN_1zo8jNJ_3BM1_7YUiFiP9oBrBY2gmUEUsnibm-pg9opq3YX9fBjUstiZMPv9fud_JB9q_-j8sP21jzMqMhco3eWqIocgMNmeBuHg7hEzJWUoOxo33-X8ICXP1-FPfYwrcNco1O6uICBZpgjq7jN6uBc11oXzOV2ZAV-e7FFz7-ArSuyyp-Z9OzBqInh97gVz3x6oMVVZM2BzsztesPgqj-UoI2-1u2M8ueibm-xQcri6i-pPcOwQAowQA-wQAJibm-XP3Oig9-wQfgwy3zpUstaHmFiQSuWyMua9fVjrOYag9Ji6sUFbm-sy9zwq3zpUs2QosnD6_KNbAJFHszPbm-X9foxQMz2gcV7guYxgIHi6srNbm-xyBY7g9o7Usti_iUDUSC5rRzwy3hSUstiyRCs9RotQRCwP3NhUiFiPMuarfB5QiUEUSyaUiFiyfhOrRzBrBY2gVYfHiUEHp1ao_-Y?t=desktop&dv=desktop&r=https%3A%2F%2Fwww.tokopedia.com%2Fbutiklampu%2Flampu-smart-led-bulb-rgb-wifi-color-light-model-philips-hue-xiaomi%3Fsrc%3Dtopads&is_search=1&page=1&ob=23&src=search&keywords=lampu&management_type=2
# Judul	:  Lampu Smart LED Bulb RGB Wifi Color light Model Philips Hue / Xiaomi
# Harga	:  Rp 69.900

# %% [markdown]
# * untuk scraping rating detail agar mengetahui detail rating per produk, maka page akan pindah ke halaman produk dan melakukan scraping terhadap detail rating.
# * Berikut kode untuk scraping detail ketika sudah masuk ke halaman produk:

# %%
driver.get("https://www.tokopedia.com/juandamart/lampu-tl-neon-t5-led-18w-120cm-tube-warna-warni-putih?trkid=f%3DCa39L000P0W0S0Sh%2CCo0Po0Fr0Cb0_src%3Dsearch_page%3D1_ob%3D1000_q%3Dlampu_bmexp%3D0_po%3D7_catid%3D1024_bmexp%3D0&whid=0")

# Waiting
script = 'document.querySelector("#zeus-root > div > div.css-1jdotmr > div:nth-child(5) > div.css-drikti.e1ufc1ph1 > div.css-nvt3av.e1ufc1ph0 > div > div:nth-child(1) > div.css-udfbf8.e1ufc1ph0 > p")'
while(driver.execute_script('return '+script) == None ):
    # Untuk trigger supaya page dapat loading
    driver.execute_script('window.scrollBy(0, 200)');
    driver.execute_script('window.scrollBy(0, 200)');
    time.sleep(.3)
    
for i in range(5):
    script = 'document.querySelector("#zeus-root > div > div.css-1jdotmr > div:nth-child(5) > div.css-drikti.e1ufc1ph1 > div.css-nvt3av.e1ufc1ph0 > div > div:nth-child({}) > div.css-udfbf8.e1ufc1ph0 > p")'.format(i+1)
    hasil= driver.execute_script('return '+script) 
    print("rating ({}): {}".format(str(i+1),hasil.text))
    
driver.quit()
# Out:
# rating (1): 367
# rating (2): 19
# rating (3): 6
# rating (4): 1
# rating (5): 7

# %% [markdown]
# * untuk mendapatkan rating, data tersebut harus di generate dengan javascript, jika langsung dengan beautifulsoup, tidak akan bisa.
# * untuk code program javascript tersebut yaitu:
# ```document.querySelector("#zeus-root > div > div.css-1jdotmr > div:nth-child(5) > div.css-drikti.e1ufc1ph1 > div.css-nvt3av.e1ufc1ph0 > div > div:nth-child(1) > div.css-udfbf8.e1ufc1ph0 > p")```
# * hasil execute javascript di atas akan menghasilkan jumlah rating yang memiliki bintang 5
# * untuk memperoleh data bintang 4 - 1, pada kode ```div:nth-child(1)``` harus di lakukan looping dengan:
# <code>
# for i in range(5):
#     script = '...div:nth-child(i+1)...'
# </code>

# %% [markdown]
# * Kesimpulan dari code scrapping di atas, maka dapat disimpulkan dalam function sebagai berikut:

# %% [markdown]
# * Fungsi **scrapingTokopedia()** pada code di bawah ini adalah fungsi yang ditujukan untuk scraping Tokopedia.

# %%
def scrappingTokopedia(linkURLTokopedia,linkTool,driver,batas):
    driver.get(linkURL+linkTool)
    driver.execute_script('window.scrollBy(0, 200)');
    
    dataNonRating=list(getAllNonRating(driver,batas)) 
    dataLink=array(dataNonRating)
    for num,link in enumerate(list(dataLink[:,0])) :
        driver.get(link)
        waitingPageRating()
        dataNonRating[num].append(list(getRating()))
    return dataNonRating

# %% [markdown]
# * Fungsi **waitingPageRating()** pada code di bawah ini untuk melakukan pengecekan "page loading" sampai complete pada produk rating, maka data dapat di scraping

# %%
def waitingPageRating():
    script = 'document.querySelector("#zeus-root > div > div.css-1jdotmr > div:nth-child(5) > div.css-drikti.e1ufc1ph1 > div.css-nvt3av.e1ufc1ph0 > div > div:nth-child(1) > div.css-udfbf8.e1ufc1ph0 > p")'
    while(driver.execute_script('return '+script) == None ):
        # Untuk trigger supaya page dapat loading
        driver.execute_script('window.scrollBy(0, 200)');
        driver.execute_script('window.scrollBy(0, -200)');
        time.sleep(.3)

# %% [markdown]
# * Fungsi **waitingPageMain()** pada code di bawah ini untuk melakukan pengecekan "page loading" sampai complete pada list semua produk tokopedia, maka data dapat di scraping

# %%
def waitingPageMain():
    script='document.querySelector("#zeus-root > div > div.css-jau1bt > div > div.css-rjanld > div.css-2imjyh > div:nth-child(1) > a > div.css-16vw0vn > div.css-11s9vse > span")'
    while(driver.execute_script('return '+script) == None ):
        # Untuk trigger supaya page dapat loading
        driver.execute_script('window.scrollBy(0, 200)');
        driver.execute_script('window.scrollBy(0, -200)');
        time.sleep(.3)

# %% [markdown]
# * Fungsi **getAllNonRating()** pada code di bawah ini untuk melakukan scraping terhadap produk kecuali data rating

# %%
def getAllNonRating(driver,batas):
    content = driver.page_source
    scrapping=BeautifulSoup(content,'lxml')
    Semua = scrapping.findAll('div', attrs={'class':'css-1g20a2m'})
    count_data = 0
    arraylink=[]
    waitingPageMain()
    for data in Semua:
        if count_data==batas:
            break
        count_data+=1
        link = data.find('a')['href']
        judul = data.find('span',attrs={'css-1bjwylw'})
        harga = data.find('span',attrs={'css-o5uqvq'})
        yield [link,judul.text,harga.text]

# %% [markdown]
# * Fungsi **getRating()** pada code di bawah ini untuk melakukan scraping data rating per produk

# %%
def getRating():
    for i in range(5):
        script = 'document.querySelector("#zeus-root > div > div.css-1jdotmr > div:nth-child(5) > div.css-drikti.e1ufc1ph1 > div.css-nvt3av.e1ufc1ph0 > div > div:nth-child({}) > div.css-udfbf8.e1ufc1ph0 > p")'.format(i+1)
        hasil= driver.execute_script('return '+script) 
        yield hasil.text

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import requests
from numpy import array
import time

linkTool=input("Mencari Barang: ")
linkTool=linkTool.replace(" ", "+")
batas=int(input("Batas Kemunculan Barang: "))
user_agent = 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.50 Safari/537.36'

options = webdriver.ChromeOptions()
options.add_argument('--incognito')
options.add_argument('--no-sandbox')
options.add_argument('user-agent={0}'.format(user_agent))
options.add_argument('--headless')
driver = webdriver.Chrome(options=options)
driver.implicitly_wait(15)
linkURLTokopedia="https://www.tokopedia.com/search?st=product&q="
try:    
    dataTokopedia = scrappingTokopedia(linkURLTokopedia,linkTool,driver,batas)
    driver.quit()
# except (Exception,NoSuchElementException) as e:
#     print(e)
#     driver.quit()
except :
    driver.quit()
# Out:
# Mencari Barang: lampu
# Batas Kemunculan Barang: 4

# %% [markdown]
# * dari function di atas, maka dapat dibuat Class Tokopedia sebagai berikut:

# %%
class Tokopedia:
    __batas=""
    __driver=""
    __linktool=""
    def __init__(self,linkURLTokopedia,linkTool,driver,batas):
        driver.get(linkURLTokopedia+linkTool)
        driver.execute_script('window.scrollBy(0, 200)');
       
    def __waitingPageRating(self):
        script = 'document.querySelector("#zeus-root > div > div.css-1jdotmr > div:nth-child(5) > div.css-drikti.e1ufc1ph1 > div.css-nvt3av.e1ufc1ph0 > div > div:nth-child(1) > div.css-udfbf8.e1ufc1ph0 > p")'
        while(driver.execute_script('return '+script) == None ):
            # Untuk trigger supaya page dapat loading
            driver.execute_script('window.scrollBy(0, 400)');
            time.sleep(.3)
            
    def __waitingPageMain(self,pos):
        script='document.querySelector("#zeus-root > div > div.css-jau1bt > div > div.css-rjanld > div.css-jza1fo > div:nth-child({})")'.format(pos)
        while(driver.execute_script('return '+script) == None ):
            # Untuk trigger supaya page dapat loading
            driver.execute_script('window.scrollBy(0, 200)');
            driver.execute_script('window.scrollBy(0, -200)');
            time.sleep(.3)
            
    def __getAllNonRating(self,driver,batas):
        content = driver.page_source
        scrapping=BeautifulSoup(content,'lxml')
        if scrapping.find(lambda tag:tag.name=="div" and "Oops" in tag.text) != "":
            return -1
        # waiting time
        self.__waitingPageMain(batas-1)
        Semua = scrapping.findAll('div', attrs={'class':'css-1g20a2m'})
        count_data = 0
        arraylink=[]
        for data in Semua:
            if count_data==batas:
                break
            count_data+=1
            link = data.find('a')['href']
            judul = data.find('span',attrs={'css-1bjwylw'})
            harga = data.find('span',attrs={'css-o5uqvq'})
            yield [link,judul.text,harga.text[3:].replace(".","")]


    def __getRating(self):
        for i in range(5):
            script = 'document.querySelector("#zeus-root > div > div.css-1jdotmr > div:nth-child(5) > div.css-drikti.e1ufc1ph1 > div.css-nvt3av.e1ufc1ph0 > div > div:nth-child({}) > div.css-udfbf8.e1ufc1ph0 > p")'.format(i+1)
            hasil= driver.execute_script('return '+script) 
            yield hasil.text if hasil != None else '0'

    def generateDataset(self):
        dataNonRating=list(self.__getAllNonRating(driver,batas)) 
        if dataNonRating == []:
            return -1
        dataLink=array(dataNonRating)
        for num,link in enumerate(list(dataLink[:,0])) :
            driver.get(link)
            if "(" in BeautifulSoup(driver.page_source,'lxml').findAll("span")[2].text:
                self.__waitingPageRating()
            dataNonRating[num].append(list(self.__getRating()))
        return dataNonRating

# %% [markdown]
# * sehingga program utamanya menjadi seperti ini:

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import requests
from numpy import array
import time

linkTool=input("Mencari Barang: ")
linkTool=linkTool.replace(" ", "+")
batas=int(input("Batas Kemunculan Barang: "))
user_agent = 'Mozilla/76.0 (X11; Linux x86_64) Chrome/75.0.3770.142 Safari/537.36'

options = webdriver.FirefoxOptions()
options.add_argument('--private')
options.add_argument('--no-sandbox')
options.add_argument('user-agent={0}'.format(user_agent))
# options.add_argument('--headless')
driver = webdriver.Firefox(options=options)
driver.implicitly_wait(15)
linkURLTokopedia="https://www.tokopedia.com/search?st=product&q="
try:    
    tokopedia = Tokopedia(linkURLTokopedia,linkTool,driver,batas)
    dataTokopedia= tokopedia.generateDataset()
    if dataTokopedia == -1:
        dataTokopedia="Not Found"
    print(dataTokopedia)
    driver.quit()
except (Exception,NoSuchElementException) as e:
    print(e)
# Out:
# Mencari Barang: lmlmwnb
# Batas Kemunculan Barang: 2
# Not Found

# %%
dataTokopedia
# Out:
# [['https://ta.tokopedia.com/promo/v1/clicks/8a-xgVY2gmUEoAehHpndHpJDUMVj9RzNrc1i6sJDUSC5rfB7q3YXUsthbm-7q3OBUstho_Kd6AyO6AUdbm-srcHi6seFHmFiy3zwrfo5rM1i6sUR6ZdaH_jhHAK76AUNH_KObm-pHOYDQfri6i-B812kgJxGgBBXZSgjH7NDZ325q1OAZ9o-Q1dFyfFN8B29zSBgHMP2_fB-H1hkypVozcHO_7zs81Oke_C6zcoN_7zuq1hAZS-q3cFpysoGqOKp_M2iH72DZ325q1OAZ9o-Q_ufyMO6QJBkQfBvzJ77_OPu8J7au9z6zV2D_SjFHJYJ19BHu7g03MO-PVBEZMhvzcx23323QJNJzMO-q9P2ysoGrVtaQIuyHB-Dy7yNrV2AZ_g-qjV2_JoGPMoWQcNxupuMy7xGPB2UuM2jzsBF3jo-ojBke3BHe72fyfODQMV9o3gsHMxfy7yNrV2AZ_g-qjV2_JoG8cz9uSBBusjF3uPj8jBkQfBizJydgjx6Hc-y8AxizJtdgjPR8jB2PfBsHjNfyfO3gBBXZSgjH7NDZ325q1Oku9BHqMrp_BzuH1OkZ_-o8Bj7_32o81B2PfBsHjNfyfO3gMHauMxsQ1N5Z325q1OkypuHqjBd_OzVP7YJ1_zoqMWd_7zuq3gzv_7ibm-Orfua9fBjUstiHmUDUMVDgaUEUSo7QuYDHOYDHBYDHZUDUMNOQ3-BrBY5gBYxgIHi6sUFbm-XP3Oig9-wy3zp9R-BrZUEHsnDUMoxPVY2gIHi6BDOoaFh6mFho_JR9ZFiQBYsy3Njq3zxPcuwy3zpUstRHmFiy3-wPcupPmUEUjdibm-FQRo79fVDgaUEUMoFyOYpqcYF9RuXrZUDUSgBrSo2Qfdi6i-fHiUDUMoxPcuSQR-N9RoOgfPBrRzwy9z7rMBiP9zBUs2QUsUpo_eibmUho_JRUBOY?t=desktop&keywords=bts&ob=23&management_type=2&src=search&page=1&dv=desktop&is_search=1&r=https%3A%2F%2Fwww.tokopedia.com%2Fbiangbuku%2Fbuku-biografi-the-best-of-bts-bonus-poster-original%3Fsrc%3Dtopads',
#   'Buku Biografi The Best Of BTS Bonus Poster Original',
#   '105000',
#   ['0', '0', '0', '0', '0']],
#  ['https://ta.tokopedia.com/promo/v1/clicks/8a-xgVY2gmUEo_HNHA17H_KDUMVj9RzNrc1i6sJDUSC5rfB7q3YXUstabm-7q3OBUstho_Kd6AyO6AUdbm-srcHi6sHOHmFiy3zwrfo5rM1i6sURHZdfosyNopUFHsKR6_rdHaFirpowQcYSUstig9BGqMzUZMggQj2fgAo6QJBkQfBoe7BpZ3O6HcoD692qu7gN3_-Sq1Y2Z_CHqBj7_S2uq1hAZS-q3cFpysoGqOKp_M2iH72DZ325q1OAZ9o-Q_ufyMO6QJBkQfBvzJ77_OPu8J7au9z6zV2D_SjFHJYJ19BHu7g03MO-PVBEZMhvzcx23323QJNJzMO-q9P2ysoGrVtaQIuyHB-Dy7yNrV2AZ_g-qjV2_JoGPMoWQcNxupuMy7xGPB2UuM2jzsBF3jo-ojBke3BHe72fyfODQMV9o3gsHMxfy7yNrV2AZ_g-qjV2_JoG8cz9uSBBusjF3uPj8jBkQfBizJydgjx6Hc-y8AxizJtdgjPR8jB2PfBsHjNfyfO3gBBXZSgjH7NDZ325q1Oku9BHqMod_7z0HjNEe9P6zJJ7_Oz-81B2PfBsHjNfyfO3gMHauMxsQ1N5Z325q1OkyRxHqBja_M20H7Oke9BvzcHO_S2S8jBXHA7ibm-Orfua9fBjUstiHmUDUMVDgaUEUSo7QuYDHOYDHBYDHZUDUMNOQ3-BrBY5gBYxgIHi6sUFbm-XP3Oig9-wy3zp9R-BrZUEHsnDUMoxPVY2gIHi6BDOoaFh6mFho_JR9ZFiQBYsy3Njq3zxPcuwy3zpUstRHmFiy3-wPcupPmUEUjdibm-FQRo79fVDgaUEUMoFyOYpqcYF9RuXrZUDUSgBrSo2Qfdi6i-fHiUDUMoDP9o7g9-wq3zwPsUi6sH7H_yNbm-sy9zBgfYa8uYpP3PSg9o79fV7PI-2ySu7gZUE3aUaHp17UiFiH_1hoa-Pwe?page=1&ob=23&r=https%3A%2F%2Fwww.tokopedia.com%2Fcutiepie-hs%2Ftransparant-card-bts-blackpink-ikon%3Fsrc%3Dtopads&r_replacement=new&keywords=bts&src=search&is_search=1&management_type=2&t=desktop&dv=desktop',
#   'TRANSPARANT CARD BTS/BLACKPINK/IKON',
#   '10000',
#   ['0', '0', '0', '0', '0']],
#  ['https://ta.tokopedia.com/promo/v1/clicks/8a-xgVY2gmUEo_Hd6_UdopHDUMVj9RzNrc1i6sJDUSC5rfB7q3YXUstpbm-7q3OBUstho_Kd6AyO6AUdbm-srcHi6sUOHmFiy3zwrfo5rM1i6sUf6ZdOHAHpoAJhHsHpHAypoaFirpowQcYSUstig9BGqMzUZMggQj2fgAo6QJBkQfBoe7BpZ3O6HcoD692qu7gN3_-Sq1Y2Z_C-q9P2y_-3o3ea69BqzsBE3_UN8u2_Z_g-qjV2_JoGP3Uao32q17jfZ32S8jYJQchouJND_VzzHB21yRz6zcrF_3jhqV2I3MBHu7ON3BzSoVBWZ_VquVVd3MB-r7BW69BxufzFyMFNqO2yeMgxuOV2_fB-P7B2PfBiH72F3s-DPuKpeSBiHBUh3_oZgMV913Bvq1BRZ3BRq3UpZSCqHMhO3Ao6QfUpeMgxuOV2_fB-P7B2PfBs3VgDyfNDgMzIzMNs81jfZ3OR8cgU8I2jzpJdgjPR83gU8Ioo81BpZ3N6qMUpZMhyHj2Nysoj8B2_Z_g-qjjh_9j78jN1qpuvucrp_92-o1N1e_z6q1BpZ3N6qMUpZMhyH7ND3uxGqMVAZ_g-qjja_OH7H1OJ_926zJud_32o8jOJ392681tNUiFiP9oBrBY2gmUEUsnibm-xQcri6i-pPcOwQAowQA-wQAJibm-XP3Oig9-wQfgwy3zpUstaHmFiQSuWyMua9fVjrOYag9Ji6sUFbm-sy9zwq3zpUs2Qo_rDH_KDH_1hoO7DUMNwyfVXgcBjy9zB9fVjraUEopnDUMVi9RzBrRei6i-6UiFircYpPVYxQcri6i-srcowrfx5rVYOQSJibm-fg9-pq3YXUstiPsUibm-sQIupPcua9fBj9RyaUstposnO6mFiyfV7g3P5rSBwrRuSgfupPVYxPIzaq3-OPc1i6BDiHsHOomUDUsJOH_ri997?t=desktop&r=https%3A%2F%2Fwww.tokopedia.com%2Fsupplierjuju%2Fsharing-bts-poster-set-official-map-of-the-soul-tour%3Fsrc%3Dtopads&page=1&src=search&r_replacement=new&dv=desktop&is_search=1&keywords=bts&ob=23&management_type=1',
#   '[sharing] BTS POSTER SET OFFICIAL MAP OF THE SOUL TOUR',
#   '100000',
#   ['0', '0', '0', '0', '0']],
#  ['https://ta.tokopedia.com/promo/v1/clicks/8a-xgVY2gmUEoAKOHpJRop1DUMVj9RzNrc1i6sJDUSC5rfB7q3YXUst7bm-7q3OBUstho_Kd6AyO6AUdbm-srcHi6sHFHmFiy3zwrfo5rM1i6sUf6ZdpopeO6_1hH_yN6_Upbm-pHOYDQfri6i-B812kgJxGgBBXZSgjH7NDZ325q1OAZ9o-Q1dFyfFN8B29zSBgHMP2_fB-8jhkz_o6zVBR_92VH7NJ39Po8j1p_jzzq1hAZS-q3cFpysoGqOKp_M2iH72DZ325q1OAZ9o-Q_ufyMO6QJBkQfBvzJ77_OPu8J7au9z6zV2D_SjFHJYJ19BHu7g03MO-PVBEZMhvzcx23323QJNJzMO-q9P2ysoGrVtaQIuyHB-Dy7yNrV2AZ_g-qjV2_JoGPMoWQcNxupuMy7xGPB2UuM2jzsBF3jo-ojBke3BHe72fyfODQMV9o3gsHMxfy7yNrV2AZ_g-qjV2_JoG8cz9uSBBusjF3uPj8jBkQfBizJydgjx6Hc-y8AxizJtdgjPR8jB2PfBsHjNfyfO3gBBXZSgjH7NDZ325q1Ok39BHqj7O_jzuH1YJgpu6uJBN_uz-q1hAZS2gHsBN3ByN8B29zSBgHMP2_fB-81NkqRuo8MHF_Bz0H1O1z_-vucWN_9BG6ZUDUSupg9-wq3ei6iUFUiFiy3hSUstirRzW9fFp9fFa9fFhUiFiQSuWyMua9fYM9fVjraUEHsnDUMNOQ3-BrBYxgIowrMuhUstaHmFiyfV79fBjraUE3p1ObA1FHiFaHp179ZFiQBYsy3Njq3zxPcuwy3zpUstRHmFiy3-wPcupPmUEUjdibm-FQRo79fVDgaUEUMoFyOYpqcYF9RuXrZUDUSgBrSo2Qfdi6i-fHiUDUMoxPcuSQR-N9RoOgfPBrRzwy9z7rMBiP9zBUs2QUsUpo_eibmUho_JRUBOY?page=1&management_type=1&is_search=1&keywords=bts&t=desktop&src=search&ob=23&dv=desktop&r=https%3A%2F%2Fwww.tokopedia.com%2Fbantalkenangan%2Fbantal-bts-dan-kpop-ukuran-27cmx55-cm-full-printing%3Fsrc%3Dtopads',
#   'Bantal BTS dan kpop ukuran 27cmx55 cm full printing',
#   '58000',
#   ['38', '1', '1', '0', '0']],
#  ['https://ta.tokopedia.com/promo/v1/clicks/8a-xgVY2gmUEo_ehopyhopHDUMVj9RzNrc1i6sJDUSC5rfB7q3YXUstObm-7q3OBUstho_Kd6AyO6AUdbm-srcHi6sHOHmFiy3zwrfo5rM1i6sUfomddH_KFoAK7Hs1doAHOHaFirpowQcYSUstig9BGqMzUZMggQj2fgAo6QJBkQfBoe7BpZ3O6HcoD692qu7gN3_-Sq1Y2Z92Hqj1F_uzoHjO1Z_V6qB1F_jzuP7Ok13BHe72a3BxDHfUpZMWyH7NkysoGQJBkQfBoe7BpZ37OPM-W_Mh-qMY2_7zooJY9u9xoHBu7_jzqQJNNHACvzVVN_VPcqO2WZ9zg8j2D_7ztquBkuMh6zJgWZ3BRq3UpZSCqHMhO3A-ZQcoc69Cqe7jfZ32Cq1hAZSgsQ3hXyurOgMoUZSgqZVgkgJyNrV2AZ_g-qjV2_JoGPMoWQcNxupuMyp-tPMoc69Cqe7jfZ32Cq1hAZSxjuOgNguyNHVB9gI2-qMY2yjzc6cgU_sCi3IKdyjzG6cgIPR2-q9P2yp-6PMoWuMggQj2fgAo6QJBkQfBoqB1F_c2zo1N1__uvzVuR_jzCoJY1Z9B-q9P2yp-6PMoWuMgsHBgtyfO6Q7BkQfBoqBjF_c2S8JYJe_CvzVVN_BzSHJOEu92-QsnYUiFiP9oBrBY2gmUEUsnibm-xQcri6i-pPcOwQAowQA-wQAJibm-XP3Oig9-wQfgwy3zpUstaHmFiQSuWyMua9fVjrOYag9Ji6sUFbm-sy9zwq3zpUs2Qo_rDH_KDH_1hoO7DUMNwyfVXgcBjy9zB9fVjraUEopnDUMVi9RzBrRei6i-6UiFircYpPVYxQcri6i-srcowrfx5rVYOQSJibm-fg9-pq3YXUstiPsUibm-sy9zBgfYa8uYpP3PSg9o79fV7PI-2ySu7gZUE3aUaHp17UiFiH_1hoa-Pwe?dv=desktop&src=search&page=1&management_type=2&ob=23&t=desktop&keywords=bts&is_search=1&r=https%3A%2F%2Fwww.tokopedia.com%2Faudiophiles%2F700-lagu-best-of-k-pop-bts-best-hits-us-single-mp3-320kb-s-fd-8gb%3Fsrc%3Dtopads',
#   '700 Lagu Best of K-Pop BTS & Best Hits US Single MP3 320KB/s & FD 8GB',
#   '150000',
#   ['0', '0', '0', '0', '0']]]

# %% [markdown]
# # Scrapping Lazada

# %% [markdown]
# * Class Lazada

# %%
class Lazada:
    driver,batas="",0
    def __init__(self,linkURLLazada,linkTool,indriver,inbatas):
        driver,batas=indriver,inbatas
        driver.get(linkURLLazada)
        driver.refresh()
        driver.execute_script('document.querySelector("#q").value="{}";'.format(linkTool.replace("+", " ")))
        driver.execute_script('document.querySelector("#topActionHeader > div > div.lzd-logo-bar > div > div.lzd-nav-search > form").submit();')
            
    # cekCaptcha Page
    def __cekCaptcha(self):
        return BeautifulSoup(driver.page_source,'lxml').find(lambda tag:tag.name=="title" and "captcha" in tag.text) != None
    
    def __prosesCaptcha(self):
        scrapping = BeautifulSoup(driver.page_source,'lxml')
        #passing recaptha slider
        while(self.__cekCaptcha()):
            if BeautifulSoup(driver.page_source,'lxml').find(id='nc_2_n1z') != None:
                src = driver.find_element_by_id('nc_2_n1z')
                ActionChains(driver).drag_and_drop_by_offset(src, 260, 0).perform()
            else:
                driver.get(driver.current_url)
                time.sleep(5)
        driver.get(driver.current_url)
        driver.execute_script('window.scrollBy(0, 200)');
    
    def __waitingPageMain(self,pos):
        script='document.querySelector("#root > div > div.ant-row.c10-Cg > div.ant-col-24 > div > div.ant-col-20.ant-col-push-4.c1z9Ut > div.c1_t2i > div:nth-child({})")'.format(pos)
        while(driver.execute_script('return '+script) == None ):
            # Untuk trigger supaya page dapat loading
            driver.execute_script('window.scrollBy(0, 200)');
            driver.execute_script('window.scrollBy(0, -200)');
            time.sleep(.3)
    
    def __getAllNonRating(self):
        scrapping = BeautifulSoup(driver.page_source,'lxml')
        if BeautifulSoup(driver.page_source,'lxml').find(lambda tag:tag.name=="div" and "Tidak" in tag.text) != "":
            return -1
        count_data = 0 #initial count dari 0
        # waiting time
        self.__waitingPageMain(batas-1)
        Semua = scrapping.findAll('div', attrs={'class':'c2prKC'})
        arraylink=[]
        for data in Semua:
            if count_data==batas:
                break
            count_data+=1            
            link = "https:"+data.find('a')['href']
            judul=data.find('div',attrs={'c16H9d'})
            harga=data.find('span',attrs={'c13VH6'})
            yield [link,judul.text,harga.text[2:].replace(".","")]


    def __getRating(self):
        for i in range(5):
            script =  'document.querySelector("#module_product_review > div > div:nth-child(1) > div.mod-rating > div > div > div.detail > ul > li:nth-child({}) > span.percent")'.format(i+1)
            hasil= driver.execute_script('return '+script) 
            script += '.textContent'
            yield driver.execute_script('return '+script)  if hasil != None else '0'

    def generateDataset(self):
        self.__prosesCaptcha()
        dataNonRating=list(self.__getAllNonRating()) 
        if dataNonRating == []:
            return -1
        dataLink=array(dataNonRating)
        for num,link in enumerate(list(dataLink[:,0])) :
            driver.get(link)
            time.sleep(0.3)
            driver.execute_script('window.scrollBy(0, 3500)');
            dataNonRating[num].append(list(self.__getRating()))
        return dataNonRating

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import requests
from numpy import array
import time
from selenium.webdriver.common.action_chains import ActionChains

linkTool=input("Mencari Barang: ")
linkTool=linkTool.replace(" ", "+")
batas=int(input("Batas Kemunculan Barang: "))
user_agent = 'Mozilla/76.0 (X11; Linux x86_64) Chrome/75.0.3770.142 Safari/537.36'
profile = webdriver.FirefoxProfile()
profile.set_preference("browser.cache.disk.enable", False)
profile.set_preference("browser.cache.memory.enable", False)
profile.set_preference("browser.cache.offline.enable", False)
profile.set_preference("network.http.use-cache", False)
options = webdriver.FirefoxOptions()
options.add_argument('--private')
options.add_argument('--no-sandbox')
options.add_argument('user-agent={0}'.format(user_agent))
# options.add_argument('--headless')
driver = webdriver.Firefox(firefox_profile=profile,options=options)
linkURLLazada="https://www.lazada.co.id/"
try:    
    lazada = Lazada(linkURLLazada,linkTool,driver,batas)
    dataLazada= lazada.generateDataset()
    if dataLazada == -1:
        dataLazada=["Not Found"]
    print(dataLazada)
    driver.quit()
except (Exception,NoSuchElementException) as e:
    print(e)
# Out:
# Mencari Barang: mhllsmnk
# Batas Kemunculan Barang: 2
# Not Found

# %% [markdown]
# # Scrapping Bukalapak

# %%
class Bukalapak:
    __batas=""
    __driver=""
    __linktool=""
    def __init__(self,linkURLBukalapak,linkTool,driver,batas):
        driver.get(linkURLBukalapak+linkTool)
        driver.execute_script('window.scrollBy(0, 200)');
       
    def __waitingPageMain(self):
        script='document.querySelector("#mod-product-list-2 > li:nth-child(1) > div > article")'
        while(driver.execute_script('return '+script) == None ):
            # Untuk trigger supaya page dapat loading
            driver.execute_script('window.scrollBy(0, 200)');
            driver.execute_script('window.scrollBy(0, -200)');
            time.sleep(.3)
            
    def __getAllNonRating(self,driver,batas):
        scrapping=BeautifulSoup( driver.page_source,'lxml')
        if scrapping.find(lambda tag:tag.name=="p" and "Maaf" in tag.text) != "":
            return -1
        # waiting time
        self.__waitingPageMain()
        Semua = scrapping.findAll('article', attrs={'class':'product-display'})
        time.sleep(0.5)
        count_data = 0
        arraylink=[]
        for data in Semua:
            if count_data==batas:
                break
            count_data+=1
            link=data.find('a')['href']
            judul=data.find('a',attrs={'product__name'})
            harga=data.find('span',attrs={'amount'})

            yield [link,judul.text,harga.text.replace(".","")]


    def __getRating(self,driver):
        scrapping=BeautifulSoup( driver.page_source,'lxml')
        data=  scrapping.findAll('span', attrs={'class':'u-fg--ash u-inline-block u-mrgn-left--3'})
        if len(data)==1:
            return ['0', '0', '0', '0', '0']
        else:
            for i in data:
                yield i.text

    def generateDataset(self):
        dataNonRating=list(self.__getAllNonRating(driver,batas))
        if dataNonRating == []:
            return -1
        dataLink=array(dataNonRating)
        for num,link in enumerate(list(dataLink[:,0])) :
            driver.get(link)
            dataNonRating[num].append(list(self.__getRating(driver)))
        return dataNonRating

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import requests
from numpy import array
import time
from selenium.webdriver.common.action_chains import ActionChains

linkTool=input("Mencari Barang: ")
linkTool=linkTool.replace(" ", "+")
batas=int(input("Batas Kemunculan Barang: "))
user_agent = 'Mozilla/76.0 (X11; Linux x86_64) Chrome/75.0.3770.142 Safari/537.36'

options = webdriver.FirefoxOptions()
options.add_argument('--private')
options.add_argument('--no-sandbox')
options.add_argument('user-agent={0}'.format(user_agent))
# options.add_argument('--headless')
driver = webdriver.Firefox(options=options)
linkURLBukalapak="https://www.bukalapak.com/products?utf8=%E2%9C%93&from_keyword_history=false&search%5Bkeywords%5D="
try:    
    bukalapak = Bukalapak(linkURLBukalapak,linkTool,driver,batas)
    dataBukalapak= bukalapak.generateDataset()
    if dataBukalapak == -1:
        dataBukalapak=["Not Found"]
    print(dataBukalapak)
    driver.quit()
except (Exception,NoSuchElementException) as e:
    print(e)

# %% [markdown]
# * Ketiga semua class sudah jadi, maka program utama menjadi:

# %% [markdown]
# * untuk mencegah IP diblokin, dibutuhkan rotating proxy dengan kode sebagai berikut:

# %% [markdown]
# * sehingga perogram utamanya menjadi:

# %% [markdown]
# * NOTE: setiap 1 tahun, name class Tokopedia selalu ganti

# %%
from lxml.html import fromstring
import requests
from itertools import cycle
import traceback

# def get_proxies():
#     url = 'https://free-proxy-list.net/'
#     response = requests.get(url)
#     parser = fromstring(response.text)
#     proxies = set()
#     for i in parser.xpath('//tbody/tr'):
#         if i.xpath('.//td[7][contains(text(),"yes")]'):
#             proxy = ":".join([i.xpath('.//td[1]/text()')[0], i.xpath('.//td[2]/text()')[0]])
#             proxies.add(proxy)
#     return proxies


# #If you are copy pasting proxy ips, put in the list below
# proxies = ['121.129.127.209:80', '124.41.215.238:45169', '185.93.3.123:8080', '194.182.64.67:3128', '106.0.38.174:8080', '163.172.175.210:3128', '13.92.196.150:8080']
# proxies = get_proxies()
# proxy_pool = cycle(proxies)

from selenium import webdriver
from bs4 import BeautifulSoup
import requests
from numpy import array
import time
from selenium.webdriver.common.action_chains import ActionChains

linkTool=input("Mencari Barang: ")
linkTool=linkTool.replace(" ", "+")
batas=int(input("Batas Kemunculan Barang: "))
user_agent = 'Mozilla/76.0 '
profile = webdriver.FirefoxProfile()
profile.set_preference("browser.cache.disk.enable", False)
profile.set_preference("browser.cache.memory.enable", False)
profile.set_preference("browser.cache.offline.enable", False)
profile.set_preference("network.http.use-cache", False)

profile.set_preference("general.useragent.override","whater_useragent")
options = webdriver.FirefoxOptions()
options.add_argument('--private')
options.add_argument('--no-sandbox')
options.add_argument('user-agent={0}'.format(user_agent))
# options.add_argument('--headless')
driver = webdriver.Firefox(firefox_profile=profile,options=options)

url = 'https://www.lazada.co.id/'

# for i in range(1,11):
#     #Get a proxy from the pool
#     proxy = next(proxy_pool)
#     print("Request #%d"%i)
#     try:
#         response = requests.get(url,proxies={"http": proxy, "https": proxy})
#         print(response.json())
#     except:
#         #Most free proxies will often get connection errors. You will have retry the entire request using another proxy to work. 
#         #We will just skip retries as its beyond the scope of this tutorial and we are only downloading a single url 
#         print("Skipping. Connnection error")
# Out:
# Mencari Barang: test
# Batas Kemunculan Barang: 5

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import requests
from numpy import array
import time
from selenium.webdriver.common.action_chains import ActionChains
import random

# mendapatkan proxy acak dari http://spys.one/en/https-ssl-proxy/
def get_proxies(driver):
    url = "http://spys.one/en/https-ssl-proxy/"
    driver.get(url)
    selectAll = 'document.querySelectorAll("font.spy14")'
    proxy=set()
    for i in driver.execute_script('return ' + selectAll):
        if ':' in i.text:
            proxy.add(i.text)
    proxies=list(proxy)
    random.shuffle(proxies)
    url="https://api.myip.com"
    for proxy in proxies:
        try:
            response = requests.get(url,proxies={"http": proxy, "https": proxy},timeout=2)
            return proxy
        except:
            pass

user_agent = 'Mozilla/76.0 (X11; Linux x86_64) Chrome/75.0.3770.142 Safari/537.36'
profile = webdriver.FirefoxProfile()
profile.set_preference("browser.cache.disk.enable", False)
profile.set_preference("browser.cache.memory.enable", False)
profile.set_preference("browser.cache.offline.enable", False)
profile.set_preference("network.http.use-cache", False)
options = webdriver.FirefoxOptions()
options.add_argument('--private')
options.add_argument('--no-sandbox')
options.add_argument('user-agent={0}'.format(user_agent))
# options.add_argument('--headless')
driverProxy = webdriver.Firefox(firefox_profile=profile,options=options)
proxy=get_proxies(driverProxy).split(":")
driverProxy.quit()
ipProxy,portProxy=proxy[0],proxy[1]

profile = webdriver.FirefoxProfile()
profile.set_preference("network.proxy.type", 1)
profile.set_preference("network.proxy.http",ipProxy)
profile.set_preference("network.proxy.http_port",int(portProxy))
profile.set_preference("network.proxy.https",ipProxy)
profile.set_preference("network.proxy.https_port",int(portProxy))
profile.set_preference("network.proxy.ssl",ipProxy)
profile.set_preference("network.proxy.ssl_port",int(portProxy))  
profile.set_preference("network.proxy.ftp",ipProxy)
profile.set_preference("network.proxy.ftp_port",int(portProxy))   
profile.set_preference("network.proxy.socks",ipProxy)
profile.set_preference("network.proxy.socks_port",int(portProxy))  
profile.update_preferences()
driver = webdriver.Firefox(firefox_profile=profile,options=options)
driver.get("https://api.myip.com")
